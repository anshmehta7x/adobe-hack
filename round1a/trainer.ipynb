# %% [markdown]
# Set input pdf file

# %%
filename = "../hackathon-task/sample-1a/Datasets/Pdfs/E0H1CM114.pdf"
output_filename = "../hackathon-task/sample-1a/Datasets/Output.json/E0H1CM114.json"

# %% [markdown]
# Extract text from all pages in the file

# %%
import extract

extractor = extract.TextExtractor(filename)
texts = extractor.extract_text_from_all_pages_multiprocessing()

dims = extractor.get_page_dimensions(0)
PAGE_WIDTH = dims["width"]
PAGE_HEIGHT = dims["height"]

print(f"Loaded {len(texts)} text snippets.")
# Out:
# Loaded 626 text snippets.

# %% [markdown]
# Sort text snippets in human-readable order

# %%
sorted_snippets = sorted(texts, key=lambda s: (s['page'], s['y_position'], s['bbox'][0]))
print(f"Sorted {len(sorted_snippets)} text snippets by page, y_position, and bbox[0].")
# Out:
# Sorted 626 text snippets by page, y_position, and bbox[0].

# %% [markdown]
# Merge snippets into lines based on position

# %%
def group_snippets_into_lines(snippets, y_tolerance=2.0):
    """
    Groups text snippets into lines based on their vertical position.
    """
    if not snippets:
        return []

    lines = []
    current_line_snippets = [snippets[0]]
    
    for i in range(1, len(snippets)):
        prev_snippet = snippets[i-1]
        current_snippet = snippets[i]
        
        # Check if snippets are on the same page and their y-positions are close
        if (current_snippet['page'] == prev_snippet['page'] and 
            abs(current_snippet['y_position'] - prev_snippet['y_position']) < y_tolerance):
            # If so, they belong to the same line
            current_line_snippets.append(current_snippet)
        else:
            # Otherwise, the previous line is finished. Finalize it and start a new one.
            lines.append(current_line_snippets)
            current_line_snippets = [current_snippet]
            
    # Add the last line
    lines.append(current_line_snippets)
    return lines

#--- Now, let's process the lines into a cleaner format ---

def process_lines(grouped_lines):
    processed_lines = []
    for line_snippets in grouped_lines:
        # Sort snippets within the line by their horizontal position
        line_snippets.sort(key=lambda s: s['bbox'][0])
        
        full_text = "".join(s['text'] for s in line_snippets).strip()
        if not full_text:
            continue
            
        # Fix trailing dots issue - specifically for table of contents entries
        # Pattern: "Title text ...... page number"
        import re
        
        # Remove table of contents dots and page numbers
        # Pattern matches strings with multiple consecutive dots followed by a number at the end
        toc_pattern = re.compile(r'^(.*?)\.{3,}\s*\d+$')
        match = toc_pattern.match(full_text)
        if match:
            # Keep only the heading text
            full_text = match.group(1).strip()
        
        # Also handle any other trailing dots (that aren't part of the TOC pattern)
        elif full_text.endswith('...') and full_text.count('.') > 3:
            full_text = full_text.rstrip('.')

        # Combine bounding boxes to get the full line's bbox
        x0 = min(s['bbox'][0] for s in line_snippets)
        y0 = min(s['bbox'][1] for s in line_snippets)
        x1 = max(s['bbox'][2] for s in line_snippets)
        y1 = max(s['bbox'][3] for s in line_snippets)
        
        # Calculate average font size (or you could use max)
        avg_font_size = sum(s['font_size'] for s in line_snippets) / len(line_snippets)
        
        processed_lines.append({
            "text": full_text,
            "page": line_snippets[0]['page'],
            "avg_font_size": avg_font_size,
            "y_position": line_snippets[0]['y_position'],
            "bbox": (x0, y0, x1, y1),
            # Keep a representative font name
            "font_name": line_snippets[0]['font_name'] 
        })
    return processed_lines

# Run the functions
grouped_lines = group_snippets_into_lines(sorted_snippets)
final_lines = process_lines(grouped_lines)

# Display the result
# for line in final_lines[1000:1004]:
#     print(line)

# %% [markdown]
# Feature Engineering
# List of features added:

# %%
from collections import Counter

def get_doc_stats(lines):
    """Calculates statistics needed for feature engineering."""
    # Find the most common font size (the body text size)
    font_sizes = [round(l['avg_font_size'], 2) for l in lines if l['text']]
    if not font_sizes:
        return {'modal_font_size': 10.0} # Default
        
    modal_font_size = Counter(font_sizes).most_common(1)[0][0]
    return {
        'modal_font_size': modal_font_size
    }

# %%
import re
import statistics

def engineer_features(lines, doc_stats):
    """
    Enriches each line with new features for ML classification.
    """
    modal_font_size = doc_stats['modal_font_size']
    
    for i, line in enumerate(lines):
        # 1. Font Weight
        font_name_lower = line['font_name'].lower()
        line['is_bold'] = any(indicator in font_name_lower for indicator in ['bold', 'black', 'heavy', 'sembold'])

        # 2. All Caps
        # isupper() is false for empty or non-alphabetic strings, which is what we want.
        # We add a length check to avoid flagging single-letter words or short acronyms.
        line['is_all_caps'] = line['text'].isupper() and len(line['text']) > 3
        
        # Note on Underline: Checking for underline requires data from the original PDF extraction
        # (often a 'flags' attribute). Since it's not in our line object, we'll skip it.
        # If you had it, you would add: line['is_underline'] = bool(line['flags'] & 2)

        # 3. Text Length
        line['text_len'] = len(line['text'])

        # 4. Starts with Numbering (using a comprehensive regex)
        # Catches: 1., 1.1, 1.1.1, A., (a), i., Chapter 1, Section A
        numbering_pattern = re.compile(
            r'^\s*(?:(?:Chapter|Section)\s+[\w\d]+|'  # "Chapter 1", "Section A"
            r'\d{1,2}(?:\.\d{1,2})*\.?|'             # "1.", "1.1", "1.1.1."
            r'[A-Z]\.|'                             # "A."
            r'\([a-z]\)|'                           # "(a)"
            r'[ivx]+\.)'                            # "i.", "iv."
        )
        line['starts_with_numbering'] = bool(numbering_pattern.match(line['text']))

        # 5. Relative Font Size
        # How much larger is this line's font than the document's main body font?
        if modal_font_size > 0:
            line['relative_font_size'] = line['avg_font_size'] / modal_font_size
        else:
            line['relative_font_size'] = 1.0

        # 6. Line Position (normalized)
        # 0.0 is top of page, 1.0 is bottom
        line['norm_y_pos'] = line['y_position'] / PAGE_HEIGHT

        # 7. Line Centering
        line_center = (line['bbox'][0] + line['bbox'][2]) / 2
        page_center = PAGE_WIDTH / 2
        # is the line's center within 10% of the page's center?
        line['is_centered'] = abs(line_center - page_center) < (0.1 * PAGE_WIDTH)

        # 8. Vertical Spacing
        space_before = -1
        space_after = -1
        
        # Space Before (compare with previous line on the same page)
        if i > 0 and lines[i-1]['page'] == line['page']:
            prev_line_bottom = lines[i-1]['bbox'][3]
            current_line_top = line['bbox'][1]
            space_before = current_line_top - prev_line_bottom
            
        # Space After (compare with next line on the same page)
        if i < len(lines) - 1 and lines[i+1]['page'] == line['page']:
            current_line_bottom = line['bbox'][3]
            next_line_top = lines[i+1]['bbox'][1]
            space_after = next_line_top - current_line_bottom

        line['space_before'] = space_before
        line['space_after'] = space_after
        
    return lines

# %%
document_stats = get_doc_stats(final_lines)
print(f"Document Statistics: {document_stats}\n")

featured_lines = engineer_features(final_lines, document_stats)
print(f"Engineered features for {len(featured_lines)} lines.\n")
import json
print(json.dumps(featured_lines, indent=1))
# Out:
# Document Statistics: {'modal_font_size': 11.04}
#
# Engineered features for 488 lines.
#
# [
#  {
#   "text": "Ontario\u2019s Libraries",
#   "page": 1,
#   "avg_font_size": 15.960000038146973,
#   "y_position": 72.08401489257812,
#   "bbox": [
#    95.44059753417969,
#    72.08401489257812,
#    238.64328002929688,
#    94.5716552734375
#   ],
#   "font_name": "Arial-Black",
#   "is_bold": true,
#   "is_all_caps": false,
#   "text_len": 19,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.4456521773683852,
#   "norm_y_pos": 0.09101517031891178,
#   "is_centered": false,
#   "space_before": -1,
#   "space_after": 0.063812255859375
#  },
#  {
#   "text": "Working Together",
#   "page": 1,
#   "avg_font_size": 15.960000038146973,
#   "y_position": 94.63546752929688,
#   "bbox": [
#    95.44059753417969,
#    94.63546752929688,
#    235.36988830566406,
#    117.12310791015625
#   ],
#   "font_name": "Arial-Black",
#   "is_bold": true,
#   "is_all_caps": false,
#   "text_len": 16,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.4456521773683852,
#   "norm_y_pos": 0.11948922667840514,
#   "is_centered": false,
#   "space_before": 0.063812255859375,
#   "space_after": 39.39283752441406
#  },
#  {
#   "text": "RFP: RRFP: RRFP: RRFP: Request fquest fquest for Prquest fr Prr Prr Proposaloposal oposaloposal",
#   "page": 1,
#   "avg_font_size": 32.040000915527344,
#   "y_position": 156.7722930908203,
#   "bbox": [
#    90.02429962158203,
#    156.5159454345703,
#    497.4065246582031,
#    201.91665649414062
#   ],
#   "font_name": "Arial-Black",
#   "is_bold": true,
#   "is_all_caps": false,
#   "text_len": 95,
#   "starts_with_numbering": false,
#   "relative_font_size": 2.90217399597168,
#   "norm_y_pos": 0.1979448145086115,
#   "is_centered": true,
#   "space_before": 39.39283752441406,
#   "space_after": 46.48333740234375
#  },
#  {
#   "text": "To Present a Proposal for Developing",
#   "page": 1,
#   "avg_font_size": 24.0,
#   "y_position": 248.39999389648438,
#   "bbox": [
#    131.80059814453125,
#    248.39999389648438,
#    482.0615234375,
#    275.1839904785156
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 36,
#   "starts_with_numbering": false,
#   "relative_font_size": 2.173913043478261,
#   "norm_y_pos": 0.3136363559299045,
#   "is_centered": true,
#   "space_before": 46.48333740234375,
#   "space_after": 0.816009521484375
#  },
#  {
#   "text": "the Business Plan for the Ontario",
#   "page": 1,
#   "avg_font_size": 24.0,
#   "y_position": 276.0,
#   "bbox": [
#    131.80059814453125,
#    276.0,
#    440.57269287109375,
#    302.78399658203125
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 33,
#   "starts_with_numbering": false,
#   "relative_font_size": 2.173913043478261,
#   "norm_y_pos": 0.3484848484848485,
#   "is_centered": true,
#   "space_before": 0.816009521484375,
#   "space_after": 0.816009521484375
#  },
#  {
#   "text": "Digital Library",
#   "page": 1,
#   "avg_font_size": 24.0,
#   "y_position": 303.6000061035156,
#   "bbox": [
#    131.80059814453125,
#    303.6000061035156,
#    262.14703369140625,
#    330.3840026855469
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 15,
#   "starts_with_numbering": false,
#   "relative_font_size": 2.173913043478261,
#   "norm_y_pos": 0.38333334103979244,
#   "is_centered": false,
#   "space_before": 0.816009521484375,
#   "space_after": 12.079803466796875
#  },
#  {
#   "text": "March 21, 2003",
#   "page": 1,
#   "avg_font_size": 20.040000915527344,
#   "y_position": 342.46380615234375,
#   "bbox": [
#    238.2406005859375,
#    342.46380615234375,
#    379.3942565917969,
#    364.8284606933594
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 14,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.8152174742325493,
#   "norm_y_pos": 0.4324037956468987,
#   "is_centered": true,
#   "space_before": 12.079803466796875,
#   "space_after": 329.4356384277344
#  },
#  {
#   "text": "The Ontario Digital Library will make Ontario a better place to study, work and live by ensuring that",
#   "page": 1,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 694.2640991210938,
#   "bbox": [
#    91.6651611328125,
#    694.2640991210938,
#    541.3319091796875,
#    708.1383666992188
#   ],
#   "font_name": "ComicSansMS",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 101,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.8765960847488558,
#   "is_centered": true,
#   "space_before": 329.4356384277344,
#   "space_after": 0.0498046875
#  },
#  {
#   "text": "all Ontario citizens have access to the knowledge and learning supports needed to be life-long",
#   "page": 1,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 708.1881713867188,
#   "bbox": [
#    91.66511535644531,
#    708.1881713867188,
#    512.4229736328125,
#    722.0624389648438
#   ],
#   "font_name": "ComicSansMS",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 94,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.8941769840741398,
#   "is_centered": true,
#   "space_before": 0.0498046875,
#   "space_after": 0.0498046875
#  },
#  {
#   "text": "learners and effective contributors towards Ontario\u2019s prosperity.",
#   "page": 1,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 722.1122436523438,
#   "bbox": [
#    91.66506958007812,
#    722.1122436523438,
#    389.48663330078125,
#    735.9865112304688
#   ],
#   "font_name": "ComicSansMS",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 65,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.9117578833994239,
#   "is_centered": false,
#   "space_before": 0.0498046875,
#   "space_after": -1
#  },
#  {
#   "text": "Ontario\u2019s Digital Library",
#   "page": 2,
#   "avg_font_size": 20.040000915527344,
#   "y_position": 88.59601593017578,
#   "bbox": [
#    90.04060363769531,
#    88.59601593017578,
#    320.04559326171875,
#    116.8323745727539
#   ],
#   "font_name": "Arial-Black",
#   "is_bold": true,
#   "is_all_caps": false,
#   "text_len": 25,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.8152174742325493,
#   "norm_y_pos": 0.11186365647749467,
#   "is_centered": false,
#   "space_before": -1,
#   "space_after": 3.4837112426757812
#  },
#  {
#   "text": "A Critical Component for Implementing Ontario\u2019s Road Map to",
#   "page": 2,
#   "avg_font_size": 15.960000038146973,
#   "y_position": 120.31608581542969,
#   "bbox": [
#    90.04060363769531,
#    120.31608581542969,
#    484.937255859375,
#    138.12744140625
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 59,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.4456521773683852,
#   "norm_y_pos": 0.15191424976695667,
#   "is_centered": true,
#   "space_before": 3.4837112426757812,
#   "space_after": 0.5426483154296875
#  },
#  {
#   "text": "Prosperity Strategy",
#   "page": 2,
#   "avg_font_size": 15.960000038146973,
#   "y_position": 138.6700897216797,
#   "bbox": [
#    90.04060363769531,
#    138.6700897216797,
#    214.4951171875,
#    156.4814453125
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 19,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.4456521773683852,
#   "norm_y_pos": 0.17508849712333294,
#   "is_centered": false,
#   "space_before": 0.5426483154296875,
#   "space_after": 39.23854064941406
#  },
#  {
#   "text": "Summary",
#   "page": 2,
#   "avg_font_size": 12.0,
#   "y_position": 195.71998596191406,
#   "bbox": [
#    96.04060363769531,
#    195.71998596191406,
#    158.74061584472656,
#    212.6279754638672
#   ],
#   "font_name": "Arial-Black",
#   "is_bold": true,
#   "is_all_caps": false,
#   "text_len": 7,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0869565217391306,
#   "norm_y_pos": 0.24712119439635613,
#   "is_centered": false,
#   "space_before": 39.23854064941406,
#   "space_after": 15.940826416015625
#  },
#  {
#   "text": "The purpose of this Request for Proposal (RFP) is to invite firms and/or consultants to",
#   "page": 2,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 228.5688018798828,
#   "bbox": [
#    96.04060363769531,
#    228.5688018798828,
#    525.30419921875,
#    240.88943481445312
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 87,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.2885969720705591,
#   "is_centered": true,
#   "space_before": 15.940826416015625,
#   "space_after": 0.2759857177734375
#  },
#  {
#   "text": "present a proposal for developing the business plan for the Ontario Digital Library (ODL).",
#   "page": 2,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 241.16542053222656,
#   "bbox": [
#    96.04061889648438,
#    241.16542053222656,
#    525.036376953125,
#    253.48605346679688
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 90,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.30450179360129614,
#   "is_centered": true,
#   "space_before": 0.2759857177734375,
#   "space_after": 0.3974456787109375
#  },
#  {
#   "text": "The ODL will deliver high-quality library electronic content to all Ontario residents in order to",
#   "page": 2,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 253.8834991455078,
#   "bbox": [
#    96.04061889648438,
#    253.8834991455078,
#    525.17333984375,
#    266.2041320800781
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 97,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.3205599736685705,
#   "is_centered": true,
#   "space_before": 0.3974456787109375,
#   "space_after": 0.397430419921875
#  },
#  {
#   "text": "assist people as they learn, work, and enhance their quality of life. The business plan to be",
#   "page": 2,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 266.6015625,
#   "bbox": [
#    96.04061889648438,
#    266.6015625,
#    525.2827758789062,
#    278.9222106933594
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 93,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.33661813446969696,
#   "is_centered": true,
#   "space_before": 0.397430419921875,
#   "space_after": 0.2760009765625
#  },
#  {
#   "text": "developed is to document and clearly communicate:",
#   "page": 2,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 279.1982116699219,
#   "bbox": [
#    96.04061889648438,
#    279.1982116699219,
#    339.90093994140625,
#    291.51885986328125
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 49,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.3525229945327296,
#   "is_centered": false,
#   "space_before": 0.2760009765625,
#   "space_after": 12.397918701171875
#  },
#  {
#   "text": "how the ODL will be implemented, including the timeline",
#   "page": 2,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 303.9167785644531,
#   "bbox": [
#    132.04205322265625,
#    303.9167785644531,
#    394.0244445800781,
#    316.2374267578125
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 55,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.3837333062682489,
#   "is_centered": true,
#   "space_before": 12.397918701171875,
#   "space_after": 0.2760009765625
#  },
#  {
#   "text": "the financial plan for the implementation",
#   "page": 2,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 316.513427734375,
#   "bbox": [
#    132.04205322265625,
#    316.513427734375,
#    319.40521240234375,
#    328.8340759277344
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 41,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.3996381663312816,
#   "is_centered": false,
#   "space_before": 0.2760009765625,
#   "space_after": 0.2760009765625
#  },
#  {
#   "text": "the financial plan for the first 2 operating years, including capital and operating costs,",
#   "page": 2,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 329.1100769042969,
#   "bbox": [
#    132.04205322265625,
#    329.1100769042969,
#    525.070556640625,
#    341.43072509765625
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 90,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.41554302639431423,
#   "is_centered": true,
#   "space_before": 0.2760009765625,
#   "space_after": 0.397430419921875
#  },
#  {
#   "text": "revenues, etc.",
#   "page": 2,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 341.8281555175781,
#   "bbox": [
#    132.63821411132812,
#    341.8281555175781,
#    201.36663818359375,
#    354.1488037109375
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 14,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.43160120646158856,
#   "is_centered": false,
#   "space_before": 0.397430419921875,
#   "space_after": 0.2760009765625
#  },
#  {
#   "text": "a financial forecast for the succeeding 2 operating years",
#   "page": 2,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 354.4248046875,
#   "bbox": [
#    132.04200744628906,
#    354.4248046875,
#    393.6560363769531,
#    366.7454528808594
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 57,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.4475060665246212,
#   "is_centered": true,
#   "space_before": 0.2760009765625,
#   "space_after": 0.397430419921875
#  },
#  {
#   "text": "the services and products to be delivered by the ODL",
#   "page": 2,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 367.14288330078125,
#   "bbox": [
#    132.04200744628906,
#    367.14288330078125,
#    381.3063049316406,
#    379.4635314941406
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 52,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.4635642465918955,
#   "is_centered": true,
#   "space_before": 0.397430419921875,
#   "space_after": 0.2760009765625
#  },
#  {
#   "text": "how the ODL will operate and be managed following the implementation",
#   "page": 2,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 379.7395324707031,
#   "bbox": [
#    132.04200744628906,
#    379.7395324707031,
#    468.61383056640625,
#    392.0601806640625
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 68,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.4794691066549282,
#   "is_centered": true,
#   "space_before": 0.2760009765625,
#   "space_after": 0.2760009765625
#  },
#  {
#   "text": "who will be involved, and what their role/responsibility will be, for both the",
#   "page": 2,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 392.336181640625,
#   "bbox": [
#    132.04200744628906,
#    392.336181640625,
#    525.1600341796875,
#    404.6568298339844
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 78,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.49537396671796086,
#   "is_centered": true,
#   "space_before": 0.2760009765625,
#   "space_after": 0.397430419921875
#  },
#  {
#   "text": "implementation and operational stages",
#   "page": 2,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 405.05426025390625,
#   "bbox": [
#    132.63816833496094,
#    405.05426025390625,
#    315.5666198730469,
#    417.3749084472656
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 37,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.5114321467852352,
#   "is_centered": false,
#   "space_before": 0.397430419921875,
#   "space_after": 0.2760009765625
#  },
#  {
#   "text": "the marketing and communications plan for the ODL",
#   "page": 2,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 417.6509094238281,
#   "bbox": [
#    132.04200744628906,
#    417.6509094238281,
#    377.3706970214844,
#    429.9715576171875
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 49,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.5273370068482678,
#   "is_centered": true,
#   "space_before": 0.2760009765625,
#   "space_after": 13.00506591796875
#  },
#  {
#   "text": "This business plan must be completed and approved by the ODL Steering Committee no",
#   "page": 2,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 442.97662353515625,
#   "bbox": [
#    96.04057312011719,
#    442.97662353515625,
#    525.2114868164062,
#    455.29730224609375
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 82,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.5593139186049952,
#   "is_centered": true,
#   "space_before": 13.00506591796875,
#   "space_after": 0.275970458984375
#  },
#  {
#   "text": "later than September 30, 2003",
#   "page": 2,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 455.5732727050781,
#   "bbox": [
#    96.04061126708984,
#    455.5732727050781,
#    240.4492950439453,
#    467.8939208984375
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 29,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.575218778668028,
#   "is_centered": false,
#   "space_before": 0.275970458984375,
#   "space_after": 12.397918701171875
#  },
#  {
#   "text": "Timeline:",
#   "page": 2,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 480.2918395996094,
#   "bbox": [
#    96.04061126708984,
#    480.2918395996094,
#    141.51548767089844,
#    492.61248779296875
#   ],
#   "font_name": "Arial-ItalicMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 9,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.6064290904035472,
#   "is_centered": false,
#   "space_before": 12.397918701171875,
#   "space_after": 12.27642822265625
#  },
#  {
#   "text": "Those firms/consultants intended to submit a proposal to this RFP must indicate their",
#   "page": 2,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 504.888916015625,
#   "bbox": [
#    96.04061126708984,
#    504.888916015625,
#    525.232421875,
#    517.2095947265625
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 85,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.6374860050702336,
#   "is_centered": true,
#   "space_before": 12.27642822265625,
#   "space_after": -0.90850830078125
#  },
#  {
#   "text": "intention to do so in an e-mail to Michael Ridley (mridley@uoguelph.ca) by April 11th.",
#   "page": 2,
#   "avg_font_size": 10.359999974568685,
#   "y_position": 517.6070556640625,
#   "bbox": [
#    96.04061126708984,
#    516.3010864257812,
#    493.13885498046875,
#    529.969482421875
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 86,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9384057947978882,
#   "norm_y_pos": 0.6535442622020992,
#   "is_centered": true,
#   "space_before": -0.90850830078125,
#   "space_after": 12.27642822265625
#  },
#  {
#   "text": "Proposals may be e-mailed, mailed, couriered or faxed to: Larry Moore",
#   "page": 2,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 542.2459106445312,
#   "bbox": [
#    96.04110717773438,
#    542.2459106445312,
#    426.18060302734375,
#    554.5665893554688
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 69,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.6846539275814788,
#   "is_centered": true,
#   "space_before": 12.27642822265625,
#   "space_after": 0.27593994140625
#  },
#  {
#   "text": "(lmoore@accessola.com), Executive Director, The Ontario Library Association, 100 Lombard",
#   "page": 2,
#   "avg_font_size": 10.769999980926514,
#   "y_position": 554.842529296875,
#   "bbox": [
#    96.04110717773438,
#    554.842529296875,
#    522.2810668945312,
#    567.1632080078125
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 88,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9755434765331987,
#   "norm_y_pos": 0.7005587491122159,
#   "is_centered": true,
#   "space_before": 0.27593994140625,
#   "space_after": 0.40557861328125
#  },
#  {
#   "text": "St., Suite 303, Toronto, ON  M5C 1M3. Proposals must be received by Noon on Monday,",
#   "page": 2,
#   "avg_font_size": 10.679999987284342,
#   "y_position": 568.5451049804688,
#   "bbox": [
#    96.04574584960938,
#    567.5687866210938,
#    506.8214416503906,
#    579.8894653320312
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 83,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9673913031960455,
#   "norm_y_pos": 0.7178599810359454,
#   "is_centered": true,
#   "space_before": 0.40557861328125,
#   "space_after": 0.27593994140625
#  },
#  {
#   "text": "April 21, 2003.",
#   "page": 2,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 580.1654052734375,
#   "bbox": [
#    96.03964233398438,
#    580.1654052734375,
#    169.33645629882812,
#    592.486083984375
#   ],
#   "font_name": "Arial-BoldItalicMT",
#   "is_bold": true,
#   "is_all_caps": false,
#   "text_len": 15,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.7325320773654513,
#   "is_centered": false,
#   "space_before": 0.27593994140625,
#   "space_after": 12.39788818359375
#  },
#  {
#   "text": "Those proposals that are short-listed will be invited to discuss their proposal during the week",
#   "page": 2,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 604.8839721679688,
#   "bbox": [
#    96.03964233398438,
#    604.8839721679688,
#    524.9611206054688,
#    617.2046508789062
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 95,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.7637423891009707,
#   "is_centered": true,
#   "space_before": 12.39788818359375,
#   "space_after": 0.27593994140625
#  },
#  {
#   "text": "of April 28, 2003. No presentation will be expected. Firms or consultants invited to an",
#   "page": 2,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 617.4805908203125,
#   "bbox": [
#    96.03964233398438,
#    617.4805908203125,
#    525.0364990234375,
#    629.80126953125
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 87,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.7796472106317077,
#   "is_centered": true,
#   "space_before": 0.27593994140625,
#   "space_after": 0.3974609375
#  },
#  {
#   "text": "interview will be expected to discuss the project and their approach with the selection",
#   "page": 2,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 630.19873046875,
#   "bbox": [
#    96.0396499633789,
#    630.19873046875,
#    525.25830078125,
#    642.5194091796875
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 87,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.7957054677635732,
#   "is_centered": true,
#   "space_before": 0.3974609375,
#   "space_after": 0.27593994140625
#  },
#  {
#   "text": "committee.",
#   "page": 2,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 642.7953491210938,
#   "bbox": [
#    96.0396499633789,
#    642.7953491210938,
#    150.654541015625,
#    655.1160278320312
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 10,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.8116102892943103,
#   "is_centered": false,
#   "space_before": 0.27593994140625,
#   "space_after": 12.27642822265625
#  },
#  {
#   "text": "Contracts with the firm/consultant will be signed the week of May 5, 2003 with the work to",
#   "page": 2,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 667.3924560546875,
#   "bbox": [
#    96.03965759277344,
#    667.3924560546875,
#    525.3057861328125,
#    679.713134765625
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 90,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.8426672424932923,
#   "is_centered": true,
#   "space_before": 12.27642822265625,
#   "space_after": 0.39739990234375
#  },
#  {
#   "text": "commence as soon as possible thereafter.",
#   "page": 2,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 680.1105346679688,
#   "bbox": [
#    96.05068969726562,
#    680.1105346679688,
#    295.826171875,
#    692.4312133789062
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 40,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.8587254225605666,
#   "is_centered": false,
#   "space_before": 0.39739990234375,
#   "space_after": 38.54864501953125
#  },
#  {
#   "text": "2",
#   "page": 2,
#   "avg_font_size": 9.0,
#   "y_position": 730.9798583984375,
#   "bbox": [
#    516.640625,
#    730.9798583984375,
#    524.650634765625,
#    743.660888671875
#   ],
#   "font_name": "Arial-BlackItalic",
#   "is_bold": true,
#   "is_all_caps": false,
#   "text_len": 1,
#   "starts_with_numbering": true,
#   "relative_font_size": 0.8152173913043479,
#   "norm_y_pos": 0.9229543666646938,
#   "is_centered": false,
#   "space_before": 38.54864501953125,
#   "space_after": -9.6226806640625
#  },
#  {
#   "text": "RFP: To Develop the Ontario Digital Library Business Plan March 2003",
#   "page": 2,
#   "avg_font_size": 7.559999942779541,
#   "y_position": 734.0382080078125,
#   "bbox": [
#    90.04060363769531,
#    734.0382080078125,
#    340.93426513671875,
#    742.4751586914062
#   ],
#   "font_name": "Arial-BoldItalicMT",
#   "is_bold": true,
#   "is_all_caps": false,
#   "text_len": 68,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.6847826035126396,
#   "norm_y_pos": 0.9268159192017834,
#   "is_centered": false,
#   "space_before": -9.6226806640625,
#   "space_after": -1
#  },
#  {
#   "text": "Please note that we reserve the right not to select any of the submitted proposals and may",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 72.20881652832031,
#   "bbox": [
#    96.04060363769531,
#    72.20881652832031,
#    525.3009033203125,
#    84.52944946289062
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 90,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.09117274814181858,
#   "is_centered": true,
#   "space_before": -1,
#   "space_after": 0.2759857177734375
#  },
#  {
#   "text": "seek further response to these Terms of Reference.",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 84.80543518066406,
#   "bbox": [
#    96.04060363769531,
#    84.80543518066406,
#    338.430419921875,
#    97.12606811523438
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 50,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.10707756967255563,
#   "is_centered": false,
#   "space_before": 0.2759857177734375,
#   "space_after": 12.397933959960938
#  },
#  {
#   "text": "If you require further information or have any questions, please contact Michael Ridley by e-",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 109.52400207519531,
#   "bbox": [
#    96.04060363769531,
#    109.52400207519531,
#    522.0972290039062,
#    121.84463500976562
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 93,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.13828788140807488,
#   "is_centered": true,
#   "space_before": 12.397933959960938,
#   "space_after": 0.2759857177734375
#  },
#  {
#   "text": "mail (mridley@uoguelph.ca) only by 3:00 p.m. on Friday April 18th. All questions and",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 122.12062072753906,
#   "bbox": [
#    96.04060363769531,
#    122.12062072753906,
#    525.0770874023438,
#    134.44125366210938
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 84,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.15419270293881196,
#   "is_centered": true,
#   "space_before": 0.2759857177734375,
#   "space_after": 0.3974456787109375
#  },
#  {
#   "text": "responses will be shared with those who have indicated that they will be submitting a",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 134.8386993408203,
#   "bbox": [
#    96.01852416992188,
#    134.8386993408203,
#    525.1431884765625,
#    147.15933227539062
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 85,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.17025088300608626,
#   "is_centered": true,
#   "space_before": 0.3974456787109375,
#   "space_after": 0.2759857177734375
#  },
#  {
#   "text": "proposal. Please note, that firms/consultants who have not indicated in an e-mail to Michael",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 147.43531799316406,
#   "bbox": [
#    96.01852416992188,
#    147.43531799316406,
#    525.0072021484375,
#    159.75595092773438
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 92,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.1861557045368233,
#   "is_centered": true,
#   "space_before": 0.2759857177734375,
#   "space_after": -1.05474853515625
#  },
#  {
#   "text": "Ridley by April 11th that they will be submitting a proposal will not receive any further",
#   "page": 3,
#   "avg_font_size": 9.679999987284342,
#   "y_position": 160.0319366455078,
#   "bbox": [
#    96.01852416992188,
#    158.70120239257812,
#    524.9852294921875,
#    172.36941528320312
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 89,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.876811593051118,
#   "norm_y_pos": 0.20206052606756036,
#   "is_centered": true,
#   "space_before": -1.05474853515625,
#   "space_after": 0.3974456787109375
#  },
#  {
#   "text": "information or question responses.",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 172.76686096191406,
#   "bbox": [
#    96.0362777709961,
#    172.76686096191406,
#    259.26715087890625,
#    185.08749389648438
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 34,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.2181399759620127,
#   "is_centered": false,
#   "space_before": 0.3974456787109375,
#   "space_after": 21.072494506835938
#  },
#  {
#   "text": "Background",
#   "page": 3,
#   "avg_font_size": 12.0,
#   "y_position": 206.1599884033203,
#   "bbox": [
#    96.04060363769531,
#    206.1599884033203,
#    174.08502197265625,
#    223.06797790527344
#   ],
#   "font_name": "Arial-Black",
#   "is_bold": true,
#   "is_all_caps": false,
#   "text_len": 10,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0869565217391306,
#   "norm_y_pos": 0.260303015660758,
#   "is_centered": false,
#   "space_before": 21.072494506835938,
#   "space_after": 16.060821533203125
#  },
#  {
#   "text": "First, some background on the ODL. For the last two years the Ontario Library Association",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 239.12879943847656,
#   "bbox": [
#    90.04060363769531,
#    239.12879943847656,
#    525.2298583984375,
#    251.44943237304688
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 89,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.3019303023213088,
#   "is_centered": true,
#   "space_before": 16.060821533203125,
#   "space_after": 0.2759857177734375
#  },
#  {
#   "text": "has acted as a catalyst, bringing together the stakeholders needed to create the Ontario",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 251.7254180908203,
#   "bbox": [
#    90.04060363769531,
#    251.7254180908203,
#    525.1958618164062,
#    264.0460510253906
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 88,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.3178351238520459,
#   "is_centered": true,
#   "space_before": 0.2759857177734375,
#   "space_after": 0.275970458984375
#  },
#  {
#   "text": "Digital Library (ODL). These stakeholders include Ontario\u2019s 5000+ public libraries, university,",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 264.322021484375,
#   "bbox": [
#    90.04060363769531,
#    264.322021484375,
#    525.1642456054688,
#    276.6426696777344
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 95,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.3337399261166351,
#   "is_centered": true,
#   "space_before": 0.275970458984375,
#   "space_after": 0.397430419921875
#  },
#  {
#   "text": "college, and school libraries, as well as Ontario government ministries.",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 277.04010009765625,
#   "bbox": [
#    90.04060363769531,
#    277.04010009765625,
#    418.03155517578125,
#    289.3607482910156
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 72,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.3497981061839094,
#   "is_centered": true,
#   "space_before": 0.397430419921875,
#   "space_after": 12.276458740234375
#  },
#  {
#   "text": "Libraries that serve very different clientele recognize that by working together they can create",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 301.63720703125,
#   "bbox": [
#    90.04060363769531,
#    301.63720703125,
#    525.2265625,
#    313.9578552246094
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 96,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.38085505938289144,
#   "is_centered": true,
#   "space_before": 12.276458740234375,
#   "space_after": 0.397430419921875
#  },
#  {
#   "text": "seamless access to quality electronic library services. Through the ODL, students will be",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 314.35528564453125,
#   "bbox": [
#    90.04060363769531,
#    314.35528564453125,
#    525.020751953125,
#    326.6759338378906
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 89,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.3969132394501657,
#   "is_centered": true,
#   "space_before": 0.397430419921875,
#   "space_after": 0.2760009765625
#  },
#  {
#   "text": "able to explore a topic at school, use the same child-safe resources after school (either at",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 326.9519348144531,
#   "bbox": [
#    90.04060363769531,
#    326.9519348144531,
#    525.2889404296875,
#    339.2725830078125
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 92,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.41281809951319837,
#   "is_centered": true,
#   "space_before": 0.2760009765625,
#   "space_after": 0.2760009765625
#  },
#  {
#   "text": "home or at a public library), enter college or university with a knowledge of how to use",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 339.548583984375,
#   "bbox": [
#    90.04060363769531,
#    339.548583984375,
#    525.1114501953125,
#    351.8692321777344
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 88,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.4287229595762311,
#   "is_centered": true,
#   "space_before": 0.2760009765625,
#   "space_after": 0.397430419921875
#  },
#  {
#   "text": "electronic resources that are still available and then, after graduation, continue to use these",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 352.26666259765625,
#   "bbox": [
#    90.04060363769531,
#    352.26666259765625,
#    525.0947265625,
#    364.5873107910156
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 95,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.44478113964350535,
#   "is_centered": true,
#   "space_before": 0.397430419921875,
#   "space_after": 0.2760009765625
#  },
#  {
#   "text": "skills and resources at work or at home.",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 364.8633117675781,
#   "bbox": [
#    90.04060363769531,
#    364.8633117675781,
#    276.89251708984375,
#    377.1839599609375
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 40,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.46068599970653806,
#   "is_centered": false,
#   "space_before": 0.2760009765625,
#   "space_after": 12.397918701171875
#  },
#  {
#   "text": "We are moving into a period of convergence. With convergence we no longer have to license",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 389.5818786621094,
#   "bbox": [
#    90.04060363769531,
#    389.5818786621094,
#    525.080322265625,
#    401.90252685546875
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 89,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.4918963114420573,
#   "is_centered": true,
#   "space_before": 12.397918701171875,
#   "space_after": 0.2760009765625
#  },
#  {
#   "text": "commercial products as individual libraries or institutions. We can work together to spend our",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 402.17852783203125,
#   "bbox": [
#    90.04060363769531,
#    402.17852783203125,
#    525.2718505859375,
#    414.4991760253906
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 94,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.50780117150509,
#   "is_centered": true,
#   "space_before": 0.2760009765625,
#   "space_after": 0.2760009765625
#  },
#  {
#   "text": "money wisely. The provincial government has made this possible by working hard to provide",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 414.7751770019531,
#   "bbox": [
#    90.04060363769531,
#    414.7751770019531,
#    524.941650390625,
#    427.0958251953125
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 89,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.5237060315681227,
#   "is_centered": true,
#   "space_before": 0.2760009765625,
#   "space_after": 0.397430419921875
#  },
#  {
#   "text": "all Ontarians with a stable, high-speed communications infrastructure. While there is still a",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 427.4932556152344,
#   "bbox": [
#    90.04060363769531,
#    427.4932556152344,
#    525.2947998046875,
#    439.81390380859375
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 93,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.5397642116353969,
#   "is_centered": true,
#   "space_before": 0.397430419921875,
#   "space_after": 0.2760009765625
#  },
#  {
#   "text": "great deal of work needed to improve this infrastructure, libraries are beginning to plan how",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 440.08990478515625,
#   "bbox": [
#    90.04060363769531,
#    440.08990478515625,
#    525.3268432617188,
#    452.4105529785156
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 93,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.5556690716984296,
#   "is_centered": true,
#   "space_before": 0.2760009765625,
#   "space_after": 0.397430419921875
#  },
#  {
#   "text": "best to exploit communications technology. We can reduce barriers to access and create the",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 452.8079833984375,
#   "bbox": [
#    90.04060363769531,
#    452.8079833984375,
#    525.2803955078125,
#    465.1286315917969
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 90,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.5717272517657039,
#   "is_centered": true,
#   "space_before": 0.397430419921875,
#   "space_after": 0.2760009765625
#  },
#  {
#   "text": "content infrastructure needed to support a knowledge society.",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 465.4046325683594,
#   "bbox": [
#    90.04060363769531,
#    465.4046325683594,
#    377.9284973144531,
#    477.72528076171875
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 61,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.5876321118287365,
#   "is_centered": false,
#   "space_before": 0.2760009765625,
#   "space_after": 12.276458740234375
#  },
#  {
#   "text": "The concept of an ODL is a key element in The Roadmap to Prosperity, a strategic plan to",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 490.0017395019531,
#   "bbox": [
#    90.04060363769531,
#    490.0017395019531,
#    509.756103515625,
#    502.3223876953125
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 88,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.6186890650277186,
#   "is_centered": true,
#   "space_before": 12.276458740234375,
#   "space_after": 0.3974609375
#  },
#  {
#   "text": "envision and attain Ontario\u2019s economic goal prepared by the Ontario Jobs and Investment",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 502.7198486328125,
#   "bbox": [
#    90.04061889648438,
#    502.7198486328125,
#    507.8970947265625,
#    515.04052734375
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 87,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.6347472836272885,
#   "is_centered": true,
#   "space_before": 0.3974609375,
#   "space_after": 0.27593994140625
#  },
#  {
#   "text": "Board. The OJIB strategic plan recommends an electronic library to \u201cconnect students to new",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 515.3164672851562,
#   "bbox": [
#    90.04061889648438,
#    515.3164672851562,
#    523.6620483398438,
#    527.6371459960938
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 91,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.6506521051580255,
#   "is_centered": true,
#   "space_before": 0.27593994140625,
#   "space_after": 0.39739990234375
#  },
#  {
#   "text": "workplaces, new sources of information and applied learning opportunities\u201d. The ODL will do",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 528.0345458984375,
#   "bbox": [
#    90.04061889648438,
#    528.0345458984375,
#    519.17431640625,
#    540.355224609375
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 91,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.6667102852252998,
#   "is_centered": true,
#   "space_before": 0.39739990234375,
#   "space_after": 0.27593994140625
#  },
#  {
#   "text": "that and much more. The ODL will connect students to electronic information, and will also",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 540.6311645507812,
#   "bbox": [
#    90.04061889648438,
#    540.6311645507812,
#    512.2785034179688,
#    552.9518432617188
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 90,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.682615106756037,
#   "is_centered": true,
#   "space_before": 0.27593994140625,
#   "space_after": 0.27593994140625
#  },
#  {
#   "text": "leverage this investment to help connect all citizens to the electronic information they need as",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 553.227783203125,
#   "bbox": [
#    90.04061889648438,
#    553.227783203125,
#    523.3850708007812,
#    565.5484619140625
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 96,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.698519928286774,
#   "is_centered": true,
#   "space_before": 0.27593994140625,
#   "space_after": 0.3974609375
#  },
#  {
#   "text": "they make decisions, solve problems and enhance their quality of life.",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 565.9459228515625,
#   "bbox": [
#    90.04061889648438,
#    565.9459228515625,
#    413.54266357421875,
#    578.2666015625
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 70,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.7145781854186395,
#   "is_centered": true,
#   "space_before": 0.3974609375,
#   "space_after": 13.00506591796875
#  },
#  {
#   "text": "Libraries have long been a key delivery point for public services. The ODL will allow that",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 591.2716674804688,
#   "bbox": [
#    90.04061889648438,
#    591.2716674804688,
#    497.93243408203125,
#    603.5923461914062
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 90,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.7465551357076625,
#   "is_centered": true,
#   "space_before": 13.00506591796875,
#   "space_after": 0.27593994140625
#  },
#  {
#   "text": "delivery point to move closer to citizens, into the smallest of libraries and even into living",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 603.8682861328125,
#   "bbox": [
#    90.04061889648438,
#    603.8682861328125,
#    497.4020080566406,
#    616.18896484375
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 94,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.7624599572383997,
#   "is_centered": true,
#   "space_before": 0.27593994140625,
#   "space_after": 0.39739990234375
#  },
#  {
#   "text": "rooms.",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 616.5863647460938,
#   "bbox": [
#    90.04061889648438,
#    616.5863647460938,
#    125.32776641845703,
#    628.9070434570312
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 6,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.7785181373056739,
#   "is_centered": false,
#   "space_before": 0.39739990234375,
#   "space_after": 12.88360595703125
#  },
#  {
#   "text": "Libraries have a long tradition of using a practical, consultative approach to solving problems,",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 641.7906494140625,
#   "bbox": [
#    90.04061889648438,
#    641.7906494140625,
#    522.2407836914062,
#    654.111328125
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 96,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9999999965446583,
#   "norm_y_pos": 0.8103417290581597,
#   "is_centered": true,
#   "space_before": 12.88360595703125,
#   "space_after": 0.3974609375
#  },
#  {
#   "text": "and of learning from others. The ODL is a very practical solution to various problems.",
#   "page": 3,
#   "avg_font_size": 11.039999961853027,
#   "y_position": 654.5087890625,
#   "bbox": [
#    90.04061889648438,
#    654.5087890625,
#    487.7761535644531,
# ...
#   "avg_font_size": 9.960000038146973,
#   "y_position": 286.455322265625,
#   "bbox": [
#    96.04039764404297,
#    286.455322265625,
#    161.5692138671875,
#    297.5706787109375
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 14,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.3616860129616477,
#   "is_centered": false,
#   "space_before": 0.408355712890625,
#   "space_after": 0.288848876953125
#  },
#  {
#   "text": "- travel guides, entertainment guides",
#   "page": 14,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 297.8595275878906,
#   "bbox": [
#    96.04039764404297,
#    297.8595275878906,
#    253.7978973388672,
#    308.9748840332031
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 37,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.3760852621059225,
#   "is_centered": false,
#   "space_before": 0.288848876953125,
#   "space_after": 0.408355712890625
#  },
#  {
#   "text": "- weather information",
#   "page": 14,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 309.38323974609375,
#   "bbox": [
#    96.04039764404297,
#    309.38323974609375,
#    187.49014282226562,
#    320.49859619140625
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 21,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.39063540371981537,
#   "is_centered": false,
#   "space_before": 0.408355712890625,
#   "space_after": 0.408355712890625
#  },
#  {
#   "text": "- media/newspapers",
#   "page": 14,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 320.9069519042969,
#   "bbox": [
#    96.04039764404297,
#    320.9069519042969,
#    184.3158721923828,
#    332.0223083496094
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 18,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.40518554533370815,
#   "is_centered": false,
#   "space_before": 0.408355712890625,
#   "space_after": 0.408355712890625
#  },
#  {
#   "text": "- leisure time, recreational activity guides",
#   "page": 14,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 332.4306640625,
#   "bbox": [
#    96.04039764404297,
#    332.4306640625,
#    268.2905578613281,
#    343.5460205078125
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 44,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.419735686947601,
#   "is_centered": false,
#   "space_before": 0.408355712890625,
#   "space_after": 0.408355712890625
#  },
#  {
#   "text": "- indexing and abstracting services",
#   "page": 14,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 343.9543762207031,
#   "bbox": [
#    96.04039764404297,
#    343.9543762207031,
#    243.89955139160156,
#    355.0697326660156
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 35,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.43428582856149384,
#   "is_centered": false,
#   "space_before": 0.408355712890625,
#   "space_after": 0.408355712890625
#  },
#  {
#   "text": "- currency converters,",
#   "page": 14,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 355.47808837890625,
#   "bbox": [
#    96.04039764404297,
#    355.47808837890625,
#    190.0030517578125,
#    366.59344482421875
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 22,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.4488359701753867,
#   "is_centered": false,
#   "space_before": 0.408355712890625,
#   "space_after": 0.288848876953125
#  },
#  {
#   "text": "- virtual reference services",
#   "page": 14,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 366.8822937011719,
#   "bbox": [
#    96.04039764404297,
#    366.8822937011719,
#    209.01170349121094,
#    377.9976501464844
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 28,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.46323521931966144,
#   "is_centered": false,
#   "space_before": 0.288848876953125,
#   "space_after": 0.408355712890625
#  },
#  {
#   "text": "-vocational/career information",
#   "page": 14,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 378.406005859375,
#   "bbox": [
#    96.04039764404297,
#    378.406005859375,
#    223.0035400390625,
#    389.5213623046875
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 30,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.4777853609335543,
#   "is_centered": false,
#   "space_before": 0.408355712890625,
#   "space_after": 0.408355712890625
#  },
#  {
#   "text": "-internet search engines",
#   "page": 14,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 389.9297180175781,
#   "bbox": [
#    96.04039764404297,
#    389.9297180175781,
#    200.0148162841797,
#    401.0450744628906
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 24,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.4923355025474471,
#   "is_centered": false,
#   "space_before": 0.408355712890625,
#   "space_after": 0.408355712890625
#  },
#  {
#   "text": "-current awareness services",
#   "page": 14,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 401.45343017578125,
#   "bbox": [
#    96.04039764404297,
#    401.45343017578125,
#    217.03160095214844,
#    412.56878662109375
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 27,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.50688564416134,
#   "is_centered": false,
#   "space_before": 0.408355712890625,
#   "space_after": 11.922119140625
#  },
#  {
#   "text": "2. Subject Guides",
#   "page": 14,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 424.49090576171875,
#   "bbox": [
#    96.03853607177734,
#    424.49090576171875,
#    173.389892578125,
#    435.60626220703125
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 17,
#   "starts_with_numbering": true,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.535973365860756,
#   "is_centered": false,
#   "space_before": 11.922119140625,
#   "space_after": 11.8026123046875
#  },
#  {
#   "text": "-arts and humanities",
#   "page": 14,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 447.40887451171875,
#   "bbox": [
#    96.03853607177734,
#    447.40887451171875,
#    184.2880859375,
#    458.52423095703125
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 20,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.564910195090554,
#   "is_centered": false,
#   "space_before": 11.8026123046875,
#   "space_after": 0.408355712890625
#  },
#  {
#   "text": "- business and economics",
#   "page": 14,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 458.9325866699219,
#   "bbox": [
#    96.03853607177734,
#    458.9325866699219,
#    208.5346221923828,
#    470.0479736328125
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 24,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.5794603367044469,
#   "is_centered": false,
#   "space_before": 0.408355712890625,
#   "space_after": 0.408355712890625
#  },
#  {
#   "text": "- education",
#   "page": 14,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 470.4563293457031,
#   "bbox": [
#    96.0404052734375,
#    470.4563293457031,
#    145.36233520507812,
#    481.5716857910156
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 11,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.5940105168506352,
#   "is_centered": false,
#   "space_before": 0.408355712890625,
#   "space_after": 0.408355712890625
#  },
#  {
#   "text": "-recreation and sports",
#   "page": 14,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 481.98004150390625,
#   "bbox": [
#    96.0404052734375,
#    481.98004150390625,
#    190.40936279296875,
#    493.09539794921875
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 22,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.6085606584645281,
#   "is_centered": false,
#   "space_before": 0.408355712890625,
#   "space_after": 0.288848876953125
#  },
#  {
#   "text": "-entertainment - games, activities for kids",
#   "page": 14,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 493.3842468261719,
#   "bbox": [
#    96.0404052734375,
#    493.3842468261719,
#    270.5028381347656,
#    504.4996643066406
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 43,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.6229599076088028,
#   "is_centered": false,
#   "space_before": 0.288848876953125,
#   "space_after": 0.408355712890625
#  },
#  {
#   "text": "-health information",
#   "page": 14,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 504.90802001953125,
#   "bbox": [
#    96.0404052734375,
#    504.90802001953125,
#    176.79708862304688,
#    516.0233764648438
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 19,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.637510126287287,
#   "is_centered": false,
#   "space_before": 0.408355712890625,
#   "space_after": 0.40838623046875
#  },
#  {
#   "text": "-science and technology",
#   "page": 14,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 516.4317626953125,
#   "bbox": [
#    96.0404052734375,
#    516.4317626953125,
#    200.96304321289062,
#    527.547119140625
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 23,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.6520603064334753,
#   "is_centered": false,
#   "space_before": 0.40838623046875,
#   "space_after": 0.4083251953125
#  },
#  {
#   "text": "-social sciences",
#   "page": 14,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 527.9554443359375,
#   "bbox": [
#    96.0404052734375,
#    527.9554443359375,
#    165.31320190429688,
#    539.07080078125
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 16,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.6666104095150726,
#   "is_centered": false,
#   "space_before": 0.4083251953125,
#   "space_after": 0.4083251953125
#  },
#  {
#   "text": "-society and culture",
#   "page": 14,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 539.4791259765625,
#   "bbox": [
#    96.0404052734375,
#    539.4791259765625,
#    180.4245147705078,
#    550.594482421875
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 20,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.6811605125966699,
#   "is_centered": false,
#   "space_before": 0.4083251953125,
#   "space_after": 11.8026123046875
#  },
#  {
#   "text": "3. Educational tool-kits",
#   "page": 14,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 562.3970947265625,
#   "bbox": [
#    96.0404052734375,
#    562.3970947265625,
#    193.4253387451172,
#    573.512451171875
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 24,
#   "starts_with_numbering": true,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.7100973418264678,
#   "is_centered": false,
#   "space_before": 11.8026123046875,
#   "space_after": 11.922119140625
#  },
#  {
#   "text": "-guides to information gathering methodologies, information literacy",
#   "page": 14,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 585.4345703125,
#   "bbox": [
#    96.0404052734375,
#    585.4345703125,
#    379.8836975097656,
#    596.5499267578125
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 68,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.7391850635258839,
#   "is_centered": false,
#   "space_before": 11.922119140625,
#   "space_after": 0.4083251953125
#  },
#  {
#   "text": "-study guides",
#   "page": 14,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 596.958251953125,
#   "bbox": [
#    96.04039001464844,
#    596.958251953125,
#    154.89105224609375,
#    608.0736083984375
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 13,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.7537351666074811,
#   "is_centered": false,
#   "space_before": 0.4083251953125,
#   "space_after": 0.40838623046875
#  },
#  {
#   "text": "-study skill development",
#   "page": 14,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 608.4819946289062,
#   "bbox": [
#    96.04039001464844,
#    608.4819946289062,
#    199.4899444580078,
#    619.5973510742188
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 24,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.7682853467536696,
#   "is_centered": false,
#   "space_before": 0.40838623046875,
#   "space_after": 0.40838623046875
#  },
#  {
#   "text": "-web-based curricula",
#   "page": 14,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 620.0057373046875,
#   "bbox": [
#    96.04039001464844,
#    620.0057373046875,
#    186.5120849609375,
#    631.12109375
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 20,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.7828355268998579,
#   "is_centered": false,
#   "space_before": 0.40838623046875,
#   "space_after": 0.28887939453125
#  },
#  {
#   "text": "-internet search guides",
#   "page": 14,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 631.4099731445312,
#   "bbox": [
#    96.04241180419922,
#    631.4099731445312,
#    194.62249755859375,
#    642.5253295898438
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 23,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.7972348145764283,
#   "is_centered": false,
#   "space_before": 0.28887939453125,
#   "space_after": 11.922119140625
#  },
#  {
#   "text": "4. Journals, books, maps, music etc.",
#   "page": 14,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 654.4474487304688,
#   "bbox": [
#    96.04241180419922,
#    654.4474487304688,
#    251.58084106445312,
#    665.5628051757812
#   ],
#   "font_name": "ArialMT",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 36,
#   "starts_with_numbering": true,
#   "relative_font_size": 0.9021739164988201,
#   "norm_y_pos": 0.8263225362758444,
#   "is_centered": false,
#   "space_before": 11.922119140625,
#   "space_after": 65.41705322265625
#  },
#  {
#   "text": "14141414",
#   "page": 14,
#   "avg_font_size": 9.0,
#   "y_position": 730.9798583984375,
#   "bbox": [
#    510.87750244140625,
#    730.9798583984375,
#    524.1669311523438,
#    743.9039306640625
#   ],
#   "font_name": "Arial-BlackItalic",
#   "is_bold": true,
#   "is_all_caps": false,
#   "text_len": 8,
#   "starts_with_numbering": true,
#   "relative_font_size": 0.8152173913043479,
#   "norm_y_pos": 0.9229543666646938,
#   "is_centered": false,
#   "space_before": 65.41705322265625,
#   "space_after": -9.86572265625
#  },
#  {
#   "text": "RFP: To Develop the Ontario Digital Library Business Plan March 2003",
#   "page": 14,
#   "avg_font_size": 7.559999942779541,
#   "y_position": 734.0382080078125,
#   "bbox": [
#    90.04060363769531,
#    734.0382080078125,
#    340.93426513671875,
#    742.4751586914062
#   ],
#   "font_name": "Arial-BoldItalicMT",
#   "is_bold": true,
#   "is_all_caps": false,
#   "text_len": 68,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.6847826035126396,
#   "norm_y_pos": 0.9268159192017834,
#   "is_centered": false,
#   "space_before": -9.86572265625,
#   "space_after": -1
#  }
# ]

# %% [markdown]
# Creating Labeled dataset

# %%
from thefuzz import fuzz
import pandas as pd



def normalize_text(text):
    """A more robust way to clean text for comparison."""
    if not isinstance(text, str):
        return ""
    text = text.lower()
    text = text.strip()
    text = re.sub(r'[\u2013\u2014]', '-', text) # Normalize dashes
    text = re.sub(r'\s+', ' ', text) # Collapse whitespace
    return text

def create_labeled_dataset_final(featured_lines, ground_truth_headings, ground_truth_title, fuzz_threshold=85):
    """
    A final, robust, and generic function to label the dataset.
    """
    # Create a lookup for ground truth headings by page
    gt_headings_by_page = {}
    for h in ground_truth_headings:
        page = h['page']
        if page not in gt_headings_by_page:
            gt_headings_by_page[page] = []
        gt_headings_by_page[page].append({
            'level': h['level'],
            'norm_text': normalize_text(h['text'])
        })
    
    # --- Generic Title Labeling ---
    # Find the line on the first page with the highest relative font size
    page_1_lines = [line for line in featured_lines if line['page'] == 1]
    if page_1_lines:
        # Find the most prominent text on page 1
        title_candidate = max(page_1_lines, key=lambda l: l['relative_font_size'])
        
        # Confirm it's a good match for the ground truth title
        norm_gt_title = normalize_text(ground_truth_title)
        
        # Special handling for titles split into two lines
        title_text_to_check = normalize_text(title_candidate['text'])
        candidate_index = featured_lines.index(title_candidate)
        if candidate_index + 1 < len(featured_lines):
            next_line = featured_lines[candidate_index+1]
            if abs(next_line['avg_font_size'] - title_candidate['avg_font_size']) < 1:
                 title_text_to_check += " " + normalize_text(next_line['text'])

        if fuzz.partial_ratio(title_text_to_check, norm_gt_title) > fuzz_threshold:
            title_candidate['label'] = 'Title'
            # Also label the next line if it was part of the combined title
            if " " in title_text_to_check:
                 featured_lines[candidate_index+1]['label'] = 'Title'
            
    # --- Label H1, H2, H3 Headings ---
    for line in featured_lines:
        line['page']  -= 1
        if 'label' in line:
            continue
            
        line['label'] = 'Body Text'
        page_num = line['page']
        
        if page_num in gt_headings_by_page:
            norm_line_text = normalize_text(line['text'])
            
            best_match = max(
                gt_headings_by_page[page_num],
                key=lambda h: fuzz.ratio(norm_line_text, h['norm_text']),
                default=None
            )
            
            if best_match:
                score = fuzz.ratio(norm_line_text, best_match['norm_text'])
                if score > fuzz_threshold:
                    line['label'] = best_match['level']
                    
    return featured_lines

# --- FINAL USAGE ---
# with open(output_filename, 'r', encoding='utf-8') as f:
#     out = json.load(f)

# corrected_outline = [
#     {**h, 'page': h['page'] + 1} for h in out['outline']
# ]

# labeled_lines = create_labeled_dataset_final(
#     featured_lines,
#     corrected_outline,
#     out['title']
# )

# df = pd.DataFrame(labeled_lines)
# print(df[df['label'] != 'Body Text'][['text', 'page', 'label']])

# %%
import json

with open(output_filename, 'r', encoding='utf-8') as f:
    out = json.load(f)
    
corrected_outline = [
    {**h, 'page': h['page'] + 1} for h in out['outline']
]

labeled_lines = create_labeled_dataset_final(
    featured_lines, 
    corrected_outline, 
    out['title']
)

df = pd.DataFrame(labeled_lines)
df.to_csv('o.csv',index=False)
# Out:
# --- Starting Match Debugger ---
#
# Checking for: 'ontario’s digital library' on Page 2
#   ✅ Best Match Found: 'rfp: to develop the ontario digital library business plan march 2003'
#   ➡️ Fuzzy Score: 49
#
# Checking for: 'a critical component for implementing ontario’s road map to prosperity strategy' on Page 2
#   ✅ Best Match Found: 'the concept of an odl is a key element in the roadmap to prosperity, a strategic plan to'
#   ➡️ Fuzzy Score: 62
#
# Checking for: 'summary' on Page 2
#   ✅ Best Match Found: 'background'
#   ➡️ Fuzzy Score: 24
#
# Checking for: 'timeline:' on Page 2
#   ✅ Best Match Found: 'information or question responses.'
#   ➡️ Fuzzy Score: 28
#
# Checking for: 'background' on Page 3
#   ✅ Best Match Found: 'shared funding:'
#   ➡️ Fuzzy Score: 40
#
# Checking for: 'equitable access for all ontarians:' on Page 4
#   ✅ Best Match Found: 'of electronic content on a consortia basis for all member libraries'
#   ➡️ Fuzzy Score: 43
#
# Checking for: 'shared decision-making and accountability:' on Page 4
#   ✅ Best Match Found: 'services envisioned for the odl’s include:'
#   ➡️ Fuzzy Score: 40
#
# Checking for: 'shared governance structure:' on Page 4
#   ✅ Best Match Found: 'resources and services'
#   ➡️ Fuzzy Score: 44
#
# Checking for: 'shared funding:' on Page 4
#   ✅ Best Match Found: 'training:'
#   ➡️ Fuzzy Score: 50
#
# Checking for: 'local points of entry:' on Page 5
#   ✅ Best Match Found: 'for each ontario library it could mean:'
#   ➡️ Fuzzy Score: 43
#
# Checking for: 'access:' on Page 5
#   ✅ Best Match Found: 'and services'
#   ➡️ Fuzzy Score: 42
#
# Checking for: 'guidance and advice:' on Page 5
#   ✅ Best Match Found: 'and services'
#   ➡️ Fuzzy Score: 50
#
# Checking for: 'training:' on Page 5
#   ✅ Best Match Found: 'implementation and operational stages'
#   ➡️ Fuzzy Score: 30
#
# Checking for: 'provincial purchasing & licensing:' on Page 5
#   ✅ Best Match Found: 'the financial plan for the implementation'
#   ➡️ Fuzzy Score: 45
#
# Checking for: 'technological support:' on Page 5
#   ✅ Best Match Found: 'knowledge supports and tools'
#   ➡️ Fuzzy Score: 48
#
# Checking for: 'what could the odl really mean?' on Page 5
#   ✅ Best Match Found: 'for the ontario government it could mean:'
#   ➡️ Fuzzy Score: 44
#
# Checking for: 'for each ontario citizen it could mean:' on Page 5
#   ✅ Best Match Found: 'for each ontario library it could mean:'
#   ➡️ Fuzzy Score: 85
#
# Checking for: 'for each ontario student it could mean:' on Page 5
#   ✅ Best Match Found: 'for each ontario library it could mean:'
#   ➡️ Fuzzy Score: 82
#
# Checking for: 'for each ontario library it could mean:' on Page 6
#   ✅ Best Match Found: 'rfp: to develop the ontario digital library business plan march 2003'
#   ➡️ Fuzzy Score: 52
#
# Checking for: 'for the ontario government it could mean:' on Page 6
#   ✅ Best Match Found: 'rfp: to develop the ontario digital library business plan march 2003'
#   ➡️ Fuzzy Score: 46
#
# Checking for: 'the business plan to be developed' on Page 6
#   ✅ Best Match Found: 'for responses to be evaluated.'
#   ➡️ Fuzzy Score: 54
#
# Checking for: 'milestones' on Page 7
#   ✅ Best Match Found: 'committee.'
#   ➡️ Fuzzy Score: 40
#
# Checking for: 'approach and specific proposal requirements' on Page 7
#   ✅ Best Match Found: 'timeline and projected completion date'
#   ➡️ Fuzzy Score: 40
#
# Checking for: 'evaluation and awarding of contract' on Page 8
#   ✅ Best Match Found: 'phase iii: operating and growing the odl'
#   ➡️ Fuzzy Score: 45
#
# Checking for: 'appendix a: odl envisioned phases & funding' on Page 9
#   ✅ Best Match Found: 'overview of odl funding model'
#   ➡️ Fuzzy Score: 42
#
# Checking for: 'phase i: business planning' on Page 9
#   ✅ Best Match Found: 'rfp: to develop the ontario digital library business plan march 2003'
#   ➡️ Fuzzy Score: 40
#
# Checking for: 'phase ii: implementing and transitioning' on Page 9
#   ✅ Best Match Found: 'represent an investment of $5.00 per citizen.'
#   ➡️ Fuzzy Score: 42
#
# Checking for: 'phase iii: operating and growing the odl' on Page 9
#   ✅ Best Match Found: 'to enhance the odl.'
#   ➡️ Fuzzy Score: 44
#
# Checking for: 'appendix b: odl steering committee terms of reference' on Page 11
#   ✅ Best Match Found: 'representatives to the steering committee.'
#   ➡️ Fuzzy Score: 53
#
# Checking for: '1. preamble' on Page 11
#   ✅ Best Match Found: '5. term'
#   ➡️ Fuzzy Score: 44
#
# Checking for: '2. terms of reference' on Page 11
#   ✅ Best Match Found: '5. term'
#   ➡️ Fuzzy Score: 43
#
# Checking for: '3. membership' on Page 11
#   ✅ Best Match Found: '7. meetings'
#   ➡️ Fuzzy Score: 50
#
# Checking for: '4. appointment criteria and process' on Page 12
#   ✅ Best Match Found: '9. financial and administrative policies'
#   ➡️ Fuzzy Score: 48
#
# Checking for: '5. term' on Page 12
#   ✅ Best Match Found: '9.3 conflict of interest:'
#   ➡️ Fuzzy Score: 31
#
# Checking for: '6. chair' on Page 12
#   ✅ Best Match Found: '9.3 conflict of interest:'
#   ➡️ Fuzzy Score: 30
#
# Checking for: '7. meetings' on Page 12
#   ✅ Best Match Found: '9.3 conflict of interest:'
#   ➡️ Fuzzy Score: 33
#
# Checking for: '8. lines of accountability and communication' on Page 12
#   ✅ Best Match Found: 'policies of the ontario library association'
#   ➡️ Fuzzy Score: 57
#
# Checking for: '9. financial and administrative policies' on Page 13
#   ✅ Best Match Found: '- indexing and abstracting services'
#   ➡️ Fuzzy Score: 56
#
# Checking for: 'appendix c: odl’s envisioned electronic resources' on Page 14
#   ❌ FAILURE: No lines were extracted for page 14. The page numbers are mismatched.
