# %% [markdown]
# Set input pdf file

# %%
filename = "../hackathon-task/sample-1a/Datasets/Pdfs/E0CCG5S312.pdf"
output_filename = "../hackathon-task/sample-1a/Datasets/Output.json/E0CCG5S312.json"

# %% [markdown]
# Extract text from all pages in the file

# %%
import extract

extractor = extract.TextExtractor(filename)
texts = extractor.extract_text_from_all_pages_multiprocessing()

dims = extractor.get_page_dimensions(0)
PAGE_WIDTH = dims["width"]
PAGE_HEIGHT = dims["height"]

print(f"Loaded {len(texts)} text snippets.")
# Out:
# Loaded 507 text snippets.

# %% [markdown]
# Sort text snippets in human-readable order

# %%
sorted_snippets = sorted(texts, key=lambda s: (s['page'], s['y_position'], s['bbox'][0]))
print(f"Sorted {len(sorted_snippets)} text snippets by page, y_position, and bbox[0].")
# Out:
# Sorted 507 text snippets by page, y_position, and bbox[0].

# %% [markdown]
# Merge snippets into lines based on position

# %%
def group_snippets_into_lines(snippets, y_tolerance=2.0):
    """
    Groups text snippets into lines based on their vertical position.
    """
    if not snippets:
        return []

    lines = []
    current_line_snippets = [snippets[0]]
    
    for i in range(1, len(snippets)):
        prev_snippet = snippets[i-1]
        current_snippet = snippets[i]
        
        # Check if snippets are on the same page and their y-positions are close
        if (current_snippet['page'] == prev_snippet['page'] and 
            abs(current_snippet['y_position'] - prev_snippet['y_position']) < y_tolerance):
            # If so, they belong to the same line
            current_line_snippets.append(current_snippet)
        else:
            # Otherwise, the previous line is finished. Finalize it and start a new one.
            lines.append(current_line_snippets)
            current_line_snippets = [current_snippet]
            
    # Add the last line
    lines.append(current_line_snippets)
    return lines

#--- Now, let's process the lines into a cleaner format ---

def process_lines(grouped_lines):
    processed_lines = []
    for line_snippets in grouped_lines:
        # Sort snippets within the line by their horizontal position
        line_snippets.sort(key=lambda s: s['bbox'][0])
        
        full_text = "".join(s['text'] for s in line_snippets).strip()
        if not full_text:
            continue
            
        # Fix trailing dots issue - specifically for table of contents entries
        # Pattern: "Title text ...... page number"
        import re
        
        # Remove table of contents dots and page numbers
        # Pattern matches strings with multiple consecutive dots followed by a number at the end
        toc_pattern = re.compile(r'^(.*?)\.{3,}\s*\d+$')
        match = toc_pattern.match(full_text)
        if match:
            # Keep only the heading text
            full_text = match.group(1).strip()
        
        # Also handle any other trailing dots (that aren't part of the TOC pattern)
        elif full_text.endswith('...') and full_text.count('.') > 3:
            full_text = full_text.rstrip('.')

        # Combine bounding boxes to get the full line's bbox
        x0 = min(s['bbox'][0] for s in line_snippets)
        y0 = min(s['bbox'][1] for s in line_snippets)
        x1 = max(s['bbox'][2] for s in line_snippets)
        y1 = max(s['bbox'][3] for s in line_snippets)
        
        # Calculate average font size (or you could use max)
        avg_font_size = sum(s['font_size'] for s in line_snippets) / len(line_snippets)
        
        processed_lines.append({
            "text": full_text,
            "page": line_snippets[0]['page'],
            "avg_font_size": avg_font_size,
            "y_position": line_snippets[0]['y_position'],
            "bbox": (x0, y0, x1, y1),
            # Keep a representative font name
            "font_name": line_snippets[0]['font_name'] 
        })
    return processed_lines

# Run the functions
grouped_lines = group_snippets_into_lines(sorted_snippets)
final_lines = process_lines(grouped_lines)

# Display the result
# for line in final_lines[1000:1004]:
#     print(line)

# %% [markdown]
# Feature Engineering
# List of features added:

# %%
from collections import Counter

def get_doc_stats(lines):
    """Calculates statistics needed for feature engineering."""
    # Find the most common font size (the body text size)
    font_sizes = [round(l['avg_font_size'], 2) for l in lines if l['text']]
    if not font_sizes:
        return {'modal_font_size': 10.0} # Default
        
    modal_font_size = Counter(font_sizes).most_common(1)[0][0]
    return {
        'modal_font_size': modal_font_size
    }

# %%
import re
import statistics

def engineer_features(lines, doc_stats):
    """
    Enriches each line with new features for ML classification.
    """
    modal_font_size = doc_stats['modal_font_size']
    
    for i, line in enumerate(lines):
        # 1. Font Weight
        font_name_lower = line['font_name'].lower()
        line['is_bold'] = any(indicator in font_name_lower for indicator in ['bold', 'black', 'heavy', 'sembold'])

        # 2. All Caps
        # isupper() is false for empty or non-alphabetic strings, which is what we want.
        # We add a length check to avoid flagging single-letter words or short acronyms.
        line['is_all_caps'] = line['text'].isupper() and len(line['text']) > 3
        
        # Note on Underline: Checking for underline requires data from the original PDF extraction
        # (often a 'flags' attribute). Since it's not in our line object, we'll skip it.
        # If you had it, you would add: line['is_underline'] = bool(line['flags'] & 2)

        # 3. Text Length
        line['text_len'] = len(line['text'])

        # 4. Starts with Numbering (using a comprehensive regex)
        # Catches: 1., 1.1, 1.1.1, A., (a), i., Chapter 1, Section A
        numbering_pattern = re.compile(
            r'^\s*(?:(?:Chapter|Section)\s+[\w\d]+|'  # "Chapter 1", "Section A"
            r'\d{1,2}(?:\.\d{1,2})*\.?|'             # "1.", "1.1", "1.1.1."
            r'[A-Z]\.|'                             # "A."
            r'\([a-z]\)|'                           # "(a)"
            r'[ivx]+\.)'                            # "i.", "iv."
        )
        line['starts_with_numbering'] = bool(numbering_pattern.match(line['text']))

        # 5. Relative Font Size
        # How much larger is this line's font than the document's main body font?
        if modal_font_size > 0:
            line['relative_font_size'] = line['avg_font_size'] / modal_font_size
        else:
            line['relative_font_size'] = 1.0

        # 6. Line Position (normalized)
        # 0.0 is top of page, 1.0 is bottom
        line['norm_y_pos'] = line['y_position'] / PAGE_HEIGHT

        # 7. Line Centering
        line_center = (line['bbox'][0] + line['bbox'][2]) / 2
        page_center = PAGE_WIDTH / 2
        # is the line's center within 10% of the page's center?
        line['is_centered'] = abs(line_center - page_center) < (0.1 * PAGE_WIDTH)

        # 8. Vertical Spacing
        space_before = -1
        space_after = -1
        
        # Space Before (compare with previous line on the same page)
        if i > 0 and lines[i-1]['page'] == line['page']:
            prev_line_bottom = lines[i-1]['bbox'][3]
            current_line_top = line['bbox'][1]
            space_before = current_line_top - prev_line_bottom
            
        # Space After (compare with next line on the same page)
        if i < len(lines) - 1 and lines[i+1]['page'] == line['page']:
            current_line_bottom = line['bbox'][3]
            next_line_top = lines[i+1]['bbox'][1]
            space_after = next_line_top - current_line_bottom

        line['space_before'] = space_before
        line['space_after'] = space_after
        
    return lines

# %%
document_stats = get_doc_stats(final_lines)
print(f"Document Statistics: {document_stats}\n")

featured_lines = engineer_features(final_lines, document_stats)
print(f"Engineered features for {len(featured_lines)} lines.\n")
import json
print(json.dumps(featured_lines, indent=1))
# Out:
# Document Statistics: {'modal_font_size': 9.96}
#
# Engineered features for 283 lines.
#
# [
#  {
#   "text": "Overview",
#   "page": 1,
#   "avg_font_size": 24.0,
#   "y_position": 189.62002563476562,
#   "bbox": [
#    252.64999389648438,
#    189.62002563476562,
#    365.9539489746094,
#    216.38002014160156
#   ],
#   "font_name": "Arial,Bold",
#   "is_bold": true,
#   "is_all_caps": false,
#   "text_len": 8,
#   "starts_with_numbering": false,
#   "relative_font_size": 2.4096385542168672,
#   "norm_y_pos": 0.23941922428632023,
#   "is_centered": true,
#   "space_before": -1,
#   "space_after": 28.464004516601562
#  },
#  {
#   "text": "Foundation Level Extensions",
#   "page": 1,
#   "avg_font_size": 24.0,
#   "y_position": 244.84402465820312,
#   "bbox": [
#    139.3459930419922,
#    244.84402465820312,
#    479.3563537597656,
#    271.6040344238281
#   ],
#   "font_name": "Arial,Bold",
#   "is_bold": true,
#   "is_all_caps": false,
#   "text_len": 27,
#   "starts_with_numbering": false,
#   "relative_font_size": 2.4096385542168672,
#   "norm_y_pos": 0.3091464957805595,
#   "is_centered": true,
#   "space_before": 28.464004516601562,
#   "space_after": 110.82598876953125
#  },
#  {
#   "text": "Version 1.0",
#   "page": 1,
#   "avg_font_size": 12.0,
#   "y_position": 382.4300231933594,
#   "bbox": [
#    275.69000244140625,
#    382.4300231933594,
#    339.8179931640625,
#    395.80999755859375
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 11,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.2048192771084336,
#   "norm_y_pos": 0.48286619090070626,
#   "is_centered": true,
#   "space_before": 110.82598876953125,
#   "space_after": 69.88998413085938
#  },
#  {
#   "text": "International Software Testing Qualifications Board",
#   "page": 1,
#   "avg_font_size": 18.0,
#   "y_position": 465.6999816894531,
#   "bbox": [
#    103.33999633789062,
#    465.6999816894531,
#    513.4158935546875,
#    485.7699890136719
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 51,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.8072289156626504,
#   "norm_y_pos": 0.5880050273856732,
#   "is_centered": true,
#   "space_before": 69.88998413085938,
#   "space_after": 166.51620483398438
#  },
#  {
#   "text": "Copyright Notice",
#   "page": 1,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 652.2861938476562,
#   "bbox": [
#    70.94400024414062,
#    652.2861938476562,
#    147.68580627441406,
#    663.3916015625
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 16,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.8235936791005761,
#   "is_centered": false,
#   "space_before": 166.51620483398438,
#   "space_after": 0.4183349609375
#  },
#  {
#   "text": "This document may be copied in its entirety, or extracts made, if the source is acknowledged.",
#   "page": 1,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 663.8099365234375,
#   "bbox": [
#    70.94400024414062,
#    663.8099365234375,
#    484.9912109375,
#    674.9153442382812
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 93,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.8381438592467645,
#   "is_centered": true,
#   "space_before": 0.4183349609375,
#   "space_after": -1
#  },
#  {
#   "text": "International",
#   "page": 2,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 38.62621307373047,
#   "bbox": [
#    447.9100036621094,
#    38.62621307373047,
#    505.6795349121094,
#    49.73161315917969
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 13,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.04877047105268999,
#   "is_centered": false,
#   "space_before": -1,
#   "space_after": -8.151611328125
#  },
#  {
#   "text": "Overview",
#   "page": 2,
#   "avg_font_size": 12.0,
#   "y_position": 41.58000183105469,
#   "bbox": [
#    74.42400360107422,
#    41.58000183105469,
#    127.78800964355469,
#    54.96000289916992
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 8,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.2048192771084336,
#   "norm_y_pos": 0.05250000231193774,
#   "is_centered": false,
#   "space_before": -8.151611328125,
#   "space_after": -4.813831329345703
#  },
#  {
#   "text": "Software Testing",
#   "page": 2,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 50.14617156982422,
#   "bbox": [
#    437.95001220703125,
#    50.14617156982422,
#    515.6878662109375,
#    61.25157165527344
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 16,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.0633158731942225,
#   "is_centered": false,
#   "space_before": -4.813831329345703,
#   "space_after": -4.299449920654297
#  },
#  {
#   "text": "Foundation Level Extension \u2013 Agile Tester",
#   "page": 2,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 58.42620086669922,
#   "bbox": [
#    74.42400360107422,
#    56.95212173461914,
#    265.065185546875,
#    70.23876190185547
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 41,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.07377045563977173,
#   "is_centered": false,
#   "space_before": -4.299449920654297,
#   "space_after": -8.57257080078125
#  },
#  {
#   "text": "Qualifications Board",
#   "page": 2,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 61.66619110107422,
#   "bbox": [
#    430.75,
#    61.66619110107422,
#    522.8401489257812,
#    72.77159118652344
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 20,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.07786135240034624,
#   "is_centered": false,
#   "space_before": -8.57257080078125,
#   "space_after": 47.59461212158203
#  },
#  {
#   "text": "Copyright \u00a9 International Software Testing Qualifications Board (hereinafter called ISTQB\u00ae).",
#   "page": 2,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 120.36620330810547,
#   "bbox": [
#    70.94400024414062,
#    120.36620330810547,
#    483.2471923828125,
#    131.4716033935547
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 92,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.1519775294294261,
#   "is_centered": true,
#   "space_before": 47.59461212158203,
#   "space_after": 587.2117462158203
#  },
#  {
#   "text": "Version 2014 Page 2 of 12 May 31, 2014",
#   "page": 2,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 718.683349609375,
#   "bbox": [
#    76.58135986328125,
#    718.683349609375,
#    533.1318359375,
#    730.0775756835938
#   ],
#   "font_name": "Trebuchet MS",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 38,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.9074284717290089,
#   "is_centered": true,
#   "space_before": 587.2117462158203,
#   "space_after": 6.81243896484375
#  },
#  {
#   "text": "\u00a9 International Software Testing Qualifications Board",
#   "page": 2,
#   "avg_font_size": 6.0,
#   "y_position": 736.8900146484375,
#   "bbox": [
#    76.58399963378906,
#    736.8900146484375,
#    219.2940216064453,
#    743.5800170898438
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 53,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.6024096385542168,
#   "norm_y_pos": 0.9304166851621686,
#   "is_centered": false,
#   "space_before": 6.81243896484375,
#   "space_after": -1
#  },
#  {
#   "text": "International",
#   "page": 3,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 38.62621307373047,
#   "bbox": [
#    447.9100036621094,
#    38.62621307373047,
#    505.6795349121094,
#    49.73161315917969
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 13,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.04877047105268999,
#   "is_centered": false,
#   "space_before": -1,
#   "space_after": -8.151611328125
#  },
#  {
#   "text": "Overview",
#   "page": 3,
#   "avg_font_size": 12.0,
#   "y_position": 41.58000183105469,
#   "bbox": [
#    74.42400360107422,
#    41.58000183105469,
#    127.78800964355469,
#    54.96000289916992
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 8,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.2048192771084336,
#   "norm_y_pos": 0.05250000231193774,
#   "is_centered": false,
#   "space_before": -8.151611328125,
#   "space_after": -4.813831329345703
#  },
#  {
#   "text": "Software Testing",
#   "page": 3,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 50.14617156982422,
#   "bbox": [
#    437.95001220703125,
#    50.14617156982422,
#    515.6878662109375,
#    61.25157165527344
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 16,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.0633158731942225,
#   "is_centered": false,
#   "space_before": -4.813831329345703,
#   "space_after": -4.299449920654297
#  },
#  {
#   "text": "Foundation Level Extension \u2013 Agile Tester",
#   "page": 3,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 58.42620086669922,
#   "bbox": [
#    74.42400360107422,
#    56.95212173461914,
#    265.065185546875,
#    70.23876190185547
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 41,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.07377045563977173,
#   "is_centered": false,
#   "space_before": -4.299449920654297,
#   "space_after": -8.57257080078125
#  },
#  {
#   "text": "Qualifications Board",
#   "page": 3,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 61.66619110107422,
#   "bbox": [
#    430.75,
#    61.66619110107422,
#    522.8402099609375,
#    72.77159118652344
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 20,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.07786135240034624,
#   "is_centered": false,
#   "space_before": -8.57257080078125,
#   "space_after": 36.16461181640625
#  },
#  {
#   "text": "Revision History",
#   "page": 3,
#   "avg_font_size": 15.960000038146973,
#   "y_position": 108.93620300292969,
#   "bbox": [
#    70.94400024414062,
#    108.93620300292969,
#    201.52871704101562,
#    126.73160552978516
#   ],
#   "font_name": "Arial,Bold",
#   "is_bold": true,
#   "is_all_caps": false,
#   "text_len": 16,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.602409642384234,
#   "norm_y_pos": 0.13754571086228495,
#   "is_centered": false,
#   "space_before": 36.16461181640625,
#   "space_after": 12.714622497558594
#  },
#  {
#   "text": "Version Date Remarks",
#   "page": 3,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 139.44622802734375,
#   "bbox": [
#    74.42400360107422,
#    139.44622802734375,
#    323.5996398925781,
#    150.55162048339844
#   ],
#   "font_name": "Arial,Bold",
#   "is_bold": true,
#   "is_all_caps": false,
#   "text_len": 20,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.17606846973149462,
#   "is_centered": false,
#   "space_before": 12.714622497558594,
#   "space_after": 1.2545928955078125
#  },
#  {
#   "text": "0.1 18 JUNE 2013 Initial version",
#   "page": 3,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 151.80621337890625,
#   "bbox": [
#    74.42400360107422,
#    151.80621337890625,
#    339.7647399902344,
#    162.91160583496094
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 32,
#   "starts_with_numbering": true,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.19167451184205334,
#   "is_centered": false,
#   "space_before": 1.2545928955078125,
#   "space_after": 1.1345977783203125
#  },
#  {
#   "text": "0.2 23 JULY 2013 WG reviewed and confirmed",
#   "page": 3,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 164.04620361328125,
#   "bbox": [
#    74.42400360107422,
#    164.04620361328125,
#    407.49273681640625,
#    175.15159606933594
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 42,
#   "starts_with_numbering": true,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.2071290449662642,
#   "is_centered": false,
#   "space_before": 1.1345977783203125,
#   "space_after": 1.1345977783203125
#  },
#  {
#   "text": "0.3 6 NOV 2013 amended population and diagram",
#   "page": 3,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 176.28619384765625,
#   "bbox": [
#    74.42400360107422,
#    176.28619384765625,
#    430.27117919921875,
#    187.39158630371094
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 45,
#   "starts_with_numbering": true,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.22258357809047508,
#   "is_centered": true,
#   "space_before": 1.1345977783203125,
#   "space_after": 1.1345977783203125
#  },
#  {
#   "text": "0.7 11 DEC 2013 Amended Business Outcomes and Chapters matching",
#   "page": 3,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 188.52618408203125,
#   "bbox": [
#    74.42400360107422,
#    188.52618408203125,
#    522.174072265625,
#    199.63157653808594
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 63,
#   "starts_with_numbering": true,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.23803811121468593,
#   "is_centered": true,
#   "space_before": 1.1345977783203125,
#   "space_after": 1.1346588134765625
#  },
#  {
#   "text": "0.8 20 DEC 2013 Working group updates on 0.7",
#   "page": 3,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 200.7662353515625,
#   "bbox": [
#    74.42400360107422,
#    200.7662353515625,
#    415.517578125,
#    211.8716278076172
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 44,
#   "starts_with_numbering": true,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.253492721403488,
#   "is_centered": true,
#   "space_before": 1.1346588134765625,
#   "space_after": 1.1345977783203125
#  },
#  {
#   "text": "1.0 31 MAY 2014 GA release for Agile Extension",
#   "page": 3,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 213.0062255859375,
#   "bbox": [
#    74.42400360107422,
#    213.0062255859375,
#    417.50457763671875,
#    224.1116180419922
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 46,
#   "starts_with_numbering": true,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.26894725452769885,
#   "is_centered": true,
#   "space_before": 1.1345977783203125,
#   "space_after": 494.57594299316406
#  },
#  {
#   "text": "Version 2014 Page 3 of 12 May 31, 2014",
#   "page": 3,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 718.6875610351562,
#   "bbox": [
#    76.58399963378906,
#    718.6875610351562,
#    533.1344604492188,
#    730.081787109375
#   ],
#   "font_name": "Trebuchet MS",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 38,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.9074337891858033,
#   "is_centered": true,
#   "space_before": 494.57594299316406,
#   "space_after": 6.8082275390625
#  },
#  {
#   "text": "\u00a9 International Software Testing Qualifications Board",
#   "page": 3,
#   "avg_font_size": 6.0,
#   "y_position": 736.8900146484375,
#   "bbox": [
#    76.58399963378906,
#    736.8900146484375,
#    219.2940216064453,
#    743.5800170898438
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 53,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.6024096385542168,
#   "norm_y_pos": 0.9304166851621686,
#   "is_centered": false,
#   "space_before": 6.8082275390625,
#   "space_after": -1
#  },
#  {
#   "text": "International",
#   "page": 4,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 38.62621307373047,
#   "bbox": [
#    447.9100036621094,
#    38.62621307373047,
#    505.6795349121094,
#    49.73161315917969
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 13,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.04877047105268999,
#   "is_centered": false,
#   "space_before": -1,
#   "space_after": -8.151611328125
#  },
#  {
#   "text": "Overview",
#   "page": 4,
#   "avg_font_size": 12.0,
#   "y_position": 41.58000183105469,
#   "bbox": [
#    74.42400360107422,
#    41.58000183105469,
#    127.78800964355469,
#    54.96000289916992
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 8,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.2048192771084336,
#   "norm_y_pos": 0.05250000231193774,
#   "is_centered": false,
#   "space_before": -8.151611328125,
#   "space_after": -4.813831329345703
#  },
#  {
#   "text": "Software Testing",
#   "page": 4,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 50.14617156982422,
#   "bbox": [
#    437.95001220703125,
#    50.14617156982422,
#    515.6878662109375,
#    61.25157165527344
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 16,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.0633158731942225,
#   "is_centered": false,
#   "space_before": -4.813831329345703,
#   "space_after": -4.299449920654297
#  },
#  {
#   "text": "Foundation Level Extension \u2013 Agile Tester",
#   "page": 4,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 58.42620086669922,
#   "bbox": [
#    74.42400360107422,
#    56.95212173461914,
#    265.065185546875,
#    70.23876190185547
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 41,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.07377045563977173,
#   "is_centered": false,
#   "space_before": -4.299449920654297,
#   "space_after": -8.57257080078125
#  },
#  {
#   "text": "Qualifications Board",
#   "page": 4,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 61.66619110107422,
#   "bbox": [
#    430.75,
#    61.66619110107422,
#    522.8401489257812,
#    72.77159118652344
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 20,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.07786135240034624,
#   "is_centered": false,
#   "space_before": -8.57257080078125,
#   "space_after": 36.16461181640625
#  },
#  {
#   "text": "Table of Contents",
#   "page": 4,
#   "avg_font_size": 15.960000038146973,
#   "y_position": 108.93620300292969,
#   "bbox": [
#    70.94400024414062,
#    108.93620300292969,
#    208.75860595703125,
#    126.73160552978516
#   ],
#   "font_name": "Arial,Bold",
#   "is_bold": true,
#   "is_all_caps": false,
#   "text_len": 17,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.602409642384234,
#   "norm_y_pos": 0.13754571086228495,
#   "is_centered": false,
#   "space_before": 36.16461181640625,
#   "space_after": 17.994590759277344
#  },
#  {
#   "text": "Revision History",
#   "page": 4,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 144.7261962890625,
#   "bbox": [
#    70.94400024414062,
#    144.7261962890625,
#    543.4862060546875,
#    155.8315887451172
#   ],
#   "font_name": "Arial,Bold",
#   "is_bold": true,
#   "is_all_caps": false,
#   "text_len": 16,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.18273509632457385,
#   "is_centered": true,
#   "space_before": 17.994590759277344,
#   "space_after": 6.2947540283203125
#  },
#  {
#   "text": "Table of Contents",
#   "page": 4,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 162.1263427734375,
#   "bbox": [
#    70.9439697265625,
#    162.1263427734375,
#    543.4862060546875,
#    173.2317352294922
#   ],
#   "font_name": "Arial,Bold",
#   "is_bold": true,
#   "is_all_caps": false,
#   "text_len": 17,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.20470497824928977,
#   "is_centered": true,
#   "space_before": 6.2947540283203125,
#   "space_after": 6.4142608642578125
#  },
#  {
#   "text": "1. Introduction to the Foundation Level Extensions",
#   "page": 4,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 179.64599609375,
#   "bbox": [
#    70.9439697265625,
#    179.64599609375,
#    543.4862060546875,
#    190.7513885498047
#   ],
#   "font_name": "Arial,Bold",
#   "is_bold": true,
#   "is_all_caps": false,
#   "text_len": 50,
#   "starts_with_numbering": true,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.22682575264362373,
#   "is_centered": true,
#   "space_before": 6.4142608642578125,
#   "space_after": 6.4142608642578125
#  },
#  {
#   "text": "2. Introduction to Foundation Level Agile Tester Extension",
#   "page": 4,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 197.1656494140625,
#   "bbox": [
#    70.9439697265625,
#    197.1656494140625,
#    543.4862060546875,
#    208.2710418701172
#   ],
#   "font_name": "Arial,Bold",
#   "is_bold": true,
#   "is_all_caps": false,
#   "text_len": 58,
#   "starts_with_numbering": true,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.2489465270379577,
#   "is_centered": true,
#   "space_before": 6.4142608642578125,
#   "space_after": 6.5337677001953125
#  },
#  {
#   "text": "2.1 Intended Audience",
#   "page": 4,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 214.8048095703125,
#   "bbox": [
#    80.90396118164062,
#    214.8048095703125,
#    543.4862060546875,
#    225.9102020263672
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 21,
#   "starts_with_numbering": true,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.2712181939019097,
#   "is_centered": true,
#   "space_before": 6.5337677001953125,
#   "space_after": 0.4183502197265625
#  },
#  {
#   "text": "2.2 Career Paths for Testers",
#   "page": 4,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 226.32855224609375,
#   "bbox": [
#    80.90396118164062,
#    226.32855224609375,
#    543.4961547851562,
#    237.43394470214844
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 28,
#   "starts_with_numbering": true,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.2857683740480982,
#   "is_centered": true,
#   "space_before": 0.4183502197265625,
#   "space_after": 0.3286895751953125
#  },
#  {
#   "text": "2.3 Learning Objectives",
#   "page": 4,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 237.76263427734375,
#   "bbox": [
#    80.91390991210938,
#    237.76263427734375,
#    543.4961547851562,
#    248.86802673339844
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 23,
#   "starts_with_numbering": true,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.30020534630977747,
#   "is_centered": true,
#   "space_before": 0.3286895751953125,
#   "space_after": 0.4183502197265625
#  },
#  {
#   "text": "2.4 Entry Requirements",
#   "page": 4,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 249.286376953125,
#   "bbox": [
#    80.91390991210938,
#    249.286376953125,
#    543.4961547851562,
#    260.39178466796875
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 22,
#   "starts_with_numbering": true,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.3147555264559659,
#   "is_centered": true,
#   "space_before": 0.4183502197265625,
#   "space_after": 0.4183349609375
#  },
#  {
#   "text": "2.5 Structure and Course Duration",
#   "page": 4,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 260.81011962890625,
#   "bbox": [
#    80.91390991210938,
#    260.81011962890625,
#    543.4961547851562,
#    271.91552734375
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 33,
#   "starts_with_numbering": true,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.32930570660215436,
#   "is_centered": true,
#   "space_before": 0.4183349609375,
#   "space_after": 0.418304443359375
#  },
#  {
#   "text": "2.6 Keeping It Current",
#   "page": 4,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 272.3338317871094,
#   "bbox": [
#    80.91390991210938,
#    272.3338317871094,
#    543.4961547851562,
#    283.4392395019531
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 22,
#   "starts_with_numbering": true,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.3438558482160472,
#   "is_centered": true,
#   "space_before": 0.418304443359375,
#   "space_after": 4.82061767578125
#  },
#  {
#   "text": "3. Overview of the Foundation Level Extension \u2013 Agile Tester Syllabus",
#   "page": 4,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 289.73394775390625,
#   "bbox": [
#    70.95391845703125,
#    288.2598571777344,
#    543.3507690429688,
#    301.5465087890625
#   ],
#   "font_name": "Arial,Bold",
#   "is_bold": true,
#   "is_all_caps": false,
#   "text_len": 69,
#   "starts_with_numbering": true,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.3658256916084675,
#   "is_centered": true,
#   "space_before": 4.82061767578125,
#   "space_after": 5.82659912109375
#  },
#  {
#   "text": "3.1 Business Outcomes",
#   "page": 4,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 307.37310791015625,
#   "bbox": [
#    80.90402221679688,
#    307.37310791015625,
#    543.3507690429688,
#    318.478515625
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 21,
#   "starts_with_numbering": true,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.3880973584724195,
#   "is_centered": true,
#   "space_before": 5.82659912109375,
#   "space_after": 0.298797607421875
#  },
#  {
#   "text": "3.2 Content",
#   "page": 4,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 318.7773132324219,
#   "bbox": [
#    80.90402221679688,
#    318.7773132324219,
#    543.3507690429688,
#    329.8827209472656
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 11,
#   "starts_with_numbering": true,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.4024966076166943,
#   "is_centered": true,
#   "space_before": 0.298797607421875,
#   "space_after": 6.294708251953125
#  },
#  {
#   "text": "4. References",
#   "page": 4,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 336.17742919921875,
#   "bbox": [
#    70.94400024414062,
#    336.17742919921875,
#    543.3507690429688,
#    347.2828369140625
#   ],
#   "font_name": "Arial,Bold",
#   "is_bold": true,
#   "is_all_caps": false,
#   "text_len": 13,
#   "starts_with_numbering": true,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.42446645100911456,
#   "is_centered": true,
#   "space_before": 6.294708251953125,
#   "space_after": 6.53375244140625
#  },
#  {
#   "text": "4.1 Trademarks",
#   "page": 4,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 353.81658935546875,
#   "bbox": [
#    80.90402221679688,
#    353.81658935546875,
#    543.3607788085938,
#    364.9219970703125
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 14,
#   "starts_with_numbering": true,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.4467381178730666,
#   "is_centered": true,
#   "space_before": 6.53375244140625,
#   "space_after": 0.418304443359375
#  },
#  {
#   "text": "4.2 Documents and Web Sites",
#   "page": 4,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 365.3403015136719,
#   "bbox": [
#    80.91403198242188,
#    365.3403015136719,
#    543.3607788085938,
#    376.4457092285156
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 27,
#   "starts_with_numbering": true,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.46128825948695945,
#   "is_centered": true,
#   "space_before": 0.418304443359375,
#   "space_after": 342.2654724121094
#  },
#  {
#   "text": "Version 2014 Page 4 of 12 May 31, 2014",
#   "page": 4,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 718.711181640625,
#   "bbox": [
#    76.601318359375,
#    718.711181640625,
#    533.1517944335938,
#    730.1054077148438
#   ],
#   "font_name": "Trebuchet MS",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 38,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.9074636131826074,
#   "is_centered": true,
#   "space_before": 342.2654724121094,
#   "space_after": 6.78460693359375
#  },
#  {
#   "text": "\u00a9 International Software Testing Qualifications Board",
#   "page": 4,
#   "avg_font_size": 6.0,
#   "y_position": 736.8900146484375,
#   "bbox": [
#    76.58399963378906,
#    736.8900146484375,
#    219.2940216064453,
#    743.5800170898438
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 53,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.6024096385542168,
#   "norm_y_pos": 0.9304166851621686,
#   "is_centered": false,
#   "space_before": 6.78460693359375,
#   "space_after": -1
#  },
#  {
#   "text": "International",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 38.62621307373047,
#   "bbox": [
#    447.9100036621094,
#    38.62621307373047,
#    505.6795349121094,
#    49.73161315917969
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 13,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.04877047105268999,
#   "is_centered": false,
#   "space_before": -1,
#   "space_after": -8.151611328125
#  },
#  {
#   "text": "Overview",
#   "page": 5,
#   "avg_font_size": 12.0,
#   "y_position": 41.58000183105469,
#   "bbox": [
#    74.42400360107422,
#    41.58000183105469,
#    127.78800964355469,
#    54.96000289916992
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 8,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.2048192771084336,
#   "norm_y_pos": 0.05250000231193774,
#   "is_centered": false,
#   "space_before": -8.151611328125,
#   "space_after": -4.813831329345703
#  },
#  {
#   "text": "Software Testing",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 50.14617156982422,
#   "bbox": [
#    437.95001220703125,
#    50.14617156982422,
#    515.6878662109375,
#    61.25157165527344
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 16,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.0633158731942225,
#   "is_centered": false,
#   "space_before": -4.813831329345703,
#   "space_after": -4.299449920654297
#  },
#  {
#   "text": "Foundation Level Extension \u2013 Agile Tester",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 58.42620086669922,
#   "bbox": [
#    74.42400360107422,
#    56.95212173461914,
#    265.065185546875,
#    70.23876190185547
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 41,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.07377045563977173,
#   "is_centered": false,
#   "space_before": -4.299449920654297,
#   "space_after": -8.57257080078125
#  },
#  {
#   "text": "Qualifications Board",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 61.66619110107422,
#   "bbox": [
#    430.75,
#    61.66619110107422,
#    522.8401489257812,
#    72.77159118652344
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 20,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.07786135240034624,
#   "is_centered": false,
#   "space_before": -8.57257080078125,
#   "space_after": 36.16461181640625
#  },
#  {
#   "text": "Acknowledgements",
#   "page": 5,
#   "avg_font_size": 15.960000038146973,
#   "y_position": 108.93620300292969,
#   "bbox": [
#    70.94400024414062,
#    108.93620300292969,
#    213.7381591796875,
#    126.73160552978516
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 16,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.602409642384234,
#   "norm_y_pos": 0.13754571086228495,
#   "is_centered": false,
#   "space_before": 36.16461181640625,
#   "space_after": 18.114585876464844
#  },
#  {
#   "text": "This document was produced by a team from the International Software Testing Qualifications Board",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 144.84619140625,
#   "bbox": [
#    70.94400024414062,
#    144.84619140625,
#    518.44384765625,
#    155.9515838623047
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 97,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.1828866053109217,
#   "is_centered": true,
#   "space_before": 18.114585876464844,
#   "space_after": 0.2987823486328125
#  },
#  {
#   "text": "Foundation Level Working Group.",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 156.2503662109375,
#   "bbox": [
#    70.94400024414062,
#    156.2503662109375,
#    222.99337768554688,
#    167.3557586669922
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 31,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.19728581592290087,
#   "is_centered": false,
#   "space_before": 0.2987823486328125,
#   "space_after": 11.932083129882812
#  },
#  {
#   "text": "The Agile Extension team thanks the review team and the National Boards for their suggestions and input.",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 179.287841796875,
#   "bbox": [
#    70.94400024414062,
#    179.287841796875,
#    542.4205322265625,
#    190.3932342529297
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 104,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.2263735376223169,
#   "is_centered": true,
#   "space_before": 11.932083129882812,
#   "space_after": 11.932083129882812
#  },
#  {
#   "text": "At the time the Foundation Level Agile Extension Syllabus was completed, the Agile Extension Working",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 202.3253173828125,
#   "bbox": [
#    70.94400024414062,
#    202.3253173828125,
#    529.7913818359375,
#    213.4307098388672
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 100,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.25546125932173297,
#   "is_centered": true,
#   "space_before": 11.932083129882812,
#   "space_after": 0.2987823486328125
#  },
#  {
#   "text": "Group had the following membership: Rex Black (Chair), Bertrand Cornanguer (Vice Chair), Gerry",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 213.7294921875,
#   "bbox": [
#    70.94400024414062,
#    213.7294921875,
#    506.2966613769531,
#    224.8348846435547
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 94,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.2698604699337121,
#   "is_centered": true,
#   "space_before": 0.2987823486328125,
#   "space_after": 0.4183502197265625
#  },
#  {
#   "text": "Coleman (Learning Objectives Lead), Debra Friedenberg (Exam Lead), Alon Linetzki (Business Outcomes",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 225.25323486328125,
#   "bbox": [
#    70.94400024414062,
#    225.25323486328125,
#    542.8787231445312,
#    236.35862731933594
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 99,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.2844106500799006,
#   "is_centered": true,
#   "space_before": 0.4183502197265625,
#   "space_after": 0.4481964111328125
#  },
#  {
#   "text": "and Marketing Lead), Tauhida Parveen (Editor), and Leo van der Aalst (Development Lead).",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 236.80682373046875,
#   "bbox": [
#    70.94400024414062,
#    236.80682373046875,
#    481.5440368652344,
#    247.91221618652344
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 88,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.29899851481119794,
#   "is_centered": true,
#   "space_before": 0.4481964111328125,
#   "space_after": 11.932083129882812
#  },
#  {
#   "text": "Authors: Rex Black, Anders Claesson, Gerry Coleman, Bertrand Cornanguer, Istvan Forgacs, Alon",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 259.84429931640625,
#   "bbox": [
#    70.94400024414062,
#    259.84429931640625,
#    509.54266357421875,
#    270.94970703125
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 93,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.32808623651061397,
#   "is_centered": true,
#   "space_before": 11.932083129882812,
#   "space_after": 0.418304443359375
#  },
#  {
#   "text": "Linetzki, Tilo Linz, Leo van der Aalst, Marie Walsh, and Stephan Weber.",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 271.3680114746094,
#   "bbox": [
#    70.94400024414062,
#    271.3680114746094,
#    391.87518310546875,
#    282.4734191894531
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 71,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.3426363781245068,
#   "is_centered": false,
#   "space_before": 0.418304443359375,
#   "space_after": 11.81256103515625
#  },
#  {
#   "text": "Internal Reviewers: Mette Bruhn-Pedersen, Christopher Clements, Alessandro Collino, Debra",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 294.2859802246094,
#   "bbox": [
#    70.94400024414062,
#    294.2859802246094,
#    486.68951416015625,
#    305.3913879394531
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 89,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.37157320735430477,
#   "is_centered": true,
#   "space_before": 11.81256103515625,
#   "space_after": 0.418304443359375
#  },
#  {
#   "text": "Friedenberg, Kari Kakkonen, Beata Karpinska, Sammy Kolluru, Jennifer Leger, Thomas Mueller, Tuula",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 305.8096923828125,
#   "bbox": [
#    70.94400024414062,
#    305.8096923828125,
#    527.4109497070312,
#    316.91510009765625
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 97,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.3861233489681976,
#   "is_centered": true,
#   "space_before": 0.418304443359375,
#   "space_after": 0.418304443359375
#  },
#  {
#   "text": "P\u00e4\u00e4kk\u00f6nen, Meile Posthuma, Gabor Puhalla, Lloyd Roden, Marko Rytk\u00f6nen, Monika Stoecklein-Olsen,",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 317.3334045410156,
#   "bbox": [
#    70.94400024414062,
#    317.3334045410156,
#    529.5333862304688,
#    328.4388122558594
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 95,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.40067349058209045,
#   "is_centered": true,
#   "space_before": 0.418304443359375,
#   "space_after": 0.418304443359375
#  },
#  {
#   "text": "Robert Treffny, Chris Van Bael, and Erik van Veenendaal.",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 328.85711669921875,
#   "bbox": [
#    70.94400024414062,
#    328.85711669921875,
#    329.8421630859375,
#    339.9625244140625
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 56,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.4152236321959833,
#   "is_centered": false,
#   "space_before": 0.418304443359375,
#   "space_after": 11.81256103515625
#  },
#  {
#   "text": "The team thanks also the following persons, from the National Boards and the Agile expert community,",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 351.77508544921875,
#   "bbox": [
#    70.94400024414062,
#    351.77508544921875,
#    527.2216186523438,
#    362.8804931640625
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 100,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.44416046142578125,
#   "is_centered": true,
#   "space_before": 11.81256103515625,
#   "space_after": 0.418304443359375
#  },
#  {
#   "text": "who participated in reviewing, commenting, and balloting of the Foundation Agile Extension Syllabus: Dani",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 363.2987976074219,
#   "bbox": [
#    70.94400024414062,
#    363.2987976074219,
#    542.8687133789062,
#    374.4043273925781
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 105,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.4587106030396741,
#   "is_centered": true,
#   "space_before": 0.418304443359375,
#   "space_after": 0.418304443359375
#  },
#  {
#   "text": "Almog, Richard Berns, Stephen Bird, Monika B\u00f6gge, Afeng Chai, Josephine Crawford, Tibor Cs\u00f6ndes,",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 374.8226318359375,
#   "bbox": [
#    70.94400024414062,
#    374.8226318359375,
#    526.3829345703125,
#    385.92803955078125
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 96,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.47326089878274935,
#   "is_centered": true,
#   "space_before": 0.418304443359375,
#   "space_after": 0.438232421875
#  },
#  {
#   "text": "Huba Demeter, Arnaud Foucal, Cyril Fumery, Kobi Halperin, Inga Hansen, Hanne Hinz, Jidong Hu, Phill",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 386.36627197265625,
#   "bbox": [
#    70.94400024414062,
#    386.36627197265625,
#    531.7335205078125,
#    397.4716796875
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 99,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.48783620198567706,
#   "is_centered": true,
#   "space_before": 0.438232421875,
#   "space_after": 0.418304443359375
#  },
#  {
#   "text": "Isles, Shirley Itah, Martin Klonk, Kjell Lauren, Igal Levi, Rik Marselis, Johan Meivert, Armin Metzger, Peter",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 397.8899841308594,
#   "bbox": [
#    70.94400024414062,
#    397.8899841308594,
#    540.6397705078125,
#    408.9953918457031
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 109,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.5023863435995699,
#   "is_centered": true,
#   "space_before": 0.418304443359375,
#   "space_after": -1.0557861328125
#  },
#  {
#   "text": "Morgan, Ninna Morin, Ingvar Nordstrom, Chris O\u2019Dea, Klaus Olsen, Ismo Paukamainen, Nathalie Phung,",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 409.4136962890625,
#   "bbox": [
#    70.94400024414062,
#    407.9396057128906,
#    536.5939331054688,
#    421.22625732421875
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 98,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.5169364852134628,
#   "is_centered": true,
#   "space_before": -1.0557861328125,
#   "space_after": -0.408355712890625
#  },
#  {
#   "text": "Helmut Pichler, Salvatore Reale, Stuart Reid, Hans Rombouts, Petri S\u00e4ilynoja, Soile Sainio, Lars-Erik",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 420.8179016113281,
#   "bbox": [
#    70.9439697265625,
#    420.8179016113281,
#    521.80029296875,
#    431.9233093261719
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 101,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.5313357343577375,
#   "is_centered": true,
#   "space_before": -0.408355712890625,
#   "space_after": 0.418304443359375
#  },
#  {
#   "text": "Sandberg, Dakar Shalom,  Jian Shen, Marco Sogliani, Lucjan Stapp, Yaron Tsubery, Sabine Uhde,",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 432.34161376953125,
#   "bbox": [
#    70.9439697265625,
#    432.34161376953125,
#    511.4658203125,
#    443.447021484375
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 93,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.5458858759716304,
#   "is_centered": true,
#   "space_before": 0.418304443359375,
#   "space_after": 0.418304443359375
#  },
#  {
#   "text": "Stephanie Ulrich, Tommi V\u00e4lim\u00e4ki, Jurian Van de Laar, Marnix Van den Ent, Ant\u00f3nio Vieira Melo, Wenye",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 443.8653259277344,
#   "bbox": [
#    70.9439697265625,
#    443.8653259277344,
#    535.6775512695312,
#    454.9707336425781
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 100,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.5604360175855232,
#   "is_centered": true,
#   "space_before": 0.418304443359375,
#   "space_after": 0.418304443359375
#  },
#  {
#   "text": "Xu, Ester Zabar, Wenqiang Zheng, Peter Zimmerer, Stevan Zivanovic, and Terry Zuo.",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 455.3890380859375,
#   "bbox": [
#    70.9439697265625,
#    455.3890380859375,
#    452.9300537109375,
#    466.49444580078125
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 81,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.574986159199416,
#   "is_centered": true,
#   "space_before": 0.418304443359375,
#   "space_after": 11.812530517578125
#  },
#  {
#   "text": "This document was formally approved for release by the General Assembly of the ISTQB\u00ae on May 31,",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 478.3069763183594,
#   "bbox": [
#    70.9439697265625,
#    478.3069763183594,
#    526.2843627929688,
#    489.41241455078125
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 96,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.6039229498969184,
#   "is_centered": true,
#   "space_before": 11.812530517578125,
#   "space_after": 0.41827392578125
#  },
#  {
#   "text": "2014.",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 489.8306884765625,
#   "bbox": [
#    70.94400024414062,
#    489.8306884765625,
#    98.54318237304688,
#    500.93609619140625
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 5,
#   "starts_with_numbering": true,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.6184730915108112,
#   "is_centered": false,
#   "space_before": 0.41827392578125,
#   "space_after": 217.8052978515625
#  },
#  {
#   "text": "Version 2014 Page 5 of 12 May 31, 2014",
#   "page": 5,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 718.7413940429688,
#   "bbox": [
#    76.58135986328125,
#    718.7413940429688,
#    533.1318359375,
#    730.1356201171875
#   ],
#   "font_name": "Trebuchet MS",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 38,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.9075017601552636,
#   "is_centered": true,
#   "space_before": 217.8052978515625,
#   "space_after": 6.75439453125
#  },
#  {
#   "text": "\u00a9 International Software Testing Qualifications Board",
#   "page": 5,
#   "avg_font_size": 6.0,
#   "y_position": 736.8900146484375,
#   "bbox": [
#    76.58399963378906,
#    736.8900146484375,
#    219.2940216064453,
#    743.5800170898438
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 53,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.6024096385542168,
#   "norm_y_pos": 0.9304166851621686,
#   "is_centered": false,
#   "space_before": 6.75439453125,
#   "space_after": -1
#  },
#  {
#   "text": "International",
#   "page": 6,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 38.62621307373047,
#   "bbox": [
#    447.9100036621094,
#    38.62621307373047,
#    505.6795349121094,
#    49.73161315917969
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 13,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.04877047105268999,
# ...
#   ],
#   "font_name": "Symbol",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 76,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.4370119499437737,
#   "is_centered": true,
#   "space_before": -1.045806884765625,
#   "space_after": -1.16534423828125
#  },
#  {
#   "text": "\uf0b7 The tester should be able to estimate testing effort based on iteration content and quality risks.",
#   "page": 11,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 358.2347717285156,
#   "bbox": [
#    88.94172668457031,
#    357.7566833496094,
#    529.4396362304688,
#    371.0433349609375
#   ],
#   "font_name": "Symbol",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 100,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.452316630970348,
#   "is_centered": true,
#   "space_before": -1.16534423828125,
#   "space_after": -1.045806884765625
#  },
#  {
#   "text": "\uf0b7 The tester should be able to interpret relevant information to support testing activities.",
#   "page": 11,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 370.4756164550781,
#   "bbox": [
#    88.94172668457031,
#    369.9975280761719,
#    486.59979248046875,
#    383.2841796875
#   ],
#   "font_name": "Symbol",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 92,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.467772242998836,
#   "is_centered": true,
#   "space_before": -1.045806884765625,
#   "space_after": -1.16534423828125
#  },
#  {
#   "text": "\uf0b7 The tester should be able to explain to business stakeholders how to define testable acceptance",
#   "page": 11,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 382.596923828125,
#   "bbox": [
#    88.94172668457031,
#    382.11883544921875,
#    543.424560546875,
#    395.4054870605469
#   ],
#   "font_name": "Symbol",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 97,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.48307692402541036,
#   "is_centered": true,
#   "space_before": -1.16534423828125,
#   "space_after": -0.388427734375
#  },
#  {
#   "text": "criteria.",
#   "page": 11,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 395.0170593261719,
#   "bbox": [
#    106.93944549560547,
#    395.0170593261719,
#    142.47671508789062,
#    406.1224670410156
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 9,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.49875891329062105,
#   "is_centered": false,
#   "space_before": -0.388427734375,
#   "space_after": -0.338653564453125
#  },
#  {
#   "text": "\uf0b7 Given a user story, the tester should be able to write acceptance test-driven development test",
#   "page": 11,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 406.26190185546875,
#   "bbox": [
#    88.94172668457031,
#    405.7838134765625,
#    543.9454956054688,
#    419.0704650878906
#   ],
#   "font_name": "Symbol",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 96,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.512956946787208,
#   "is_centered": true,
#   "space_before": -0.338653564453125,
#   "space_after": -0.288848876953125
#  },
#  {
#   "text": "cases.",
#   "page": 11,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 418.7816162109375,
#   "bbox": [
#    106.93944549560547,
#    418.7816162109375,
#    138.6371307373047,
#    429.88702392578125
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 6,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.528764666933002,
#   "is_centered": false,
#   "space_before": -0.288848876953125,
#   "space_after": -0.338653564453125
#  },
#  {
#   "text": "\uf0b7 For both functional and non-functional behavior, the tester should be able to write test cases using",
#   "page": 11,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 430.0264587402344,
#   "bbox": [
#    88.94172668457031,
#    429.5483703613281,
#    543.8259887695312,
#    442.83502197265625
#   ],
#   "font_name": "Symbol",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 102,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.5429627004295888,
#   "is_centered": true,
#   "space_before": -0.338653564453125,
#   "space_after": -0.408355712890625
#  },
#  {
#   "text": "black box test design techniques based on given user stories.",
#   "page": 11,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 442.4266662597656,
#   "bbox": [
#    106.93944549560547,
#    442.4266662597656,
#    382.16717529296875,
#    453.5320739746094
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 61,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.5586195281057647,
#   "is_centered": false,
#   "space_before": -0.408355712890625,
#   "space_after": -0.338653564453125
#  },
#  {
#   "text": "\uf0b7 The tester should be able to perform exploratory testing to support the testing of an Agile project.",
#   "page": 11,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 453.6715087890625,
#   "bbox": [
#    88.94172668457031,
#    453.19342041015625,
#    536.6398315429688,
#    466.4800720214844
#   ],
#   "font_name": "Symbol",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 102,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.5728175616023516,
#   "is_centered": true,
#   "space_before": -0.338653564453125,
#   "space_after": -1.16534423828125
#  },
#  {
#   "text": "\uf0b7 The tester should be able to recall different tools available to testers according to their purpose",
#   "page": 11,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 465.7928161621094,
#   "bbox": [
#    88.94172668457031,
#    465.3147277832031,
#    543.4564208984375,
#    478.60137939453125
#   ],
#   "font_name": "Symbol",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 101,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.588122242628926,
#   "is_centered": true,
#   "space_before": -1.16534423828125,
#   "space_after": -0.288848876953125
#  },
#  {
#   "text": "and to activities in Agile projects.",
#   "page": 11,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 478.3125305175781,
#   "bbox": [
#    106.93944549560547,
#    478.3125305175781,
#    254.94699096679688,
#    489.4179382324219
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 36,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.6039299627747199,
#   "is_centered": false,
#   "space_before": -0.288848876953125,
#   "space_after": 229.32901000976562
#  },
#  {
#   "text": "Version 2014 Page 11 of 12 May 31, 2014",
#   "page": 11,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 718.7469482421875,
#   "bbox": [
#    76.58135986328125,
#    718.7469482421875,
#    533.1318359375,
#    730.1411743164062
#   ],
#   "font_name": "Trebuchet MS",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 39,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.907508773033065,
#   "is_centered": true,
#   "space_before": 229.32901000976562,
#   "space_after": 6.74884033203125
#  },
#  {
#   "text": "\u00a9 International Software Testing Qualifications Board",
#   "page": 11,
#   "avg_font_size": 6.0,
#   "y_position": 736.8900146484375,
#   "bbox": [
#    76.58399963378906,
#    736.8900146484375,
#    219.2940216064453,
#    743.5800170898438
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 53,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.6024096385542168,
#   "norm_y_pos": 0.9304166851621686,
#   "is_centered": false,
#   "space_before": 6.74884033203125,
#   "space_after": -1
#  },
#  {
#   "text": "International",
#   "page": 12,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 38.62621307373047,
#   "bbox": [
#    447.9100036621094,
#    38.62621307373047,
#    505.6795349121094,
#    49.73161315917969
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 13,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.04877047105268999,
#   "is_centered": false,
#   "space_before": -1,
#   "space_after": -8.151611328125
#  },
#  {
#   "text": "Overview",
#   "page": 12,
#   "avg_font_size": 12.0,
#   "y_position": 41.58000183105469,
#   "bbox": [
#    74.42400360107422,
#    41.58000183105469,
#    127.78800964355469,
#    54.96000289916992
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 8,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.2048192771084336,
#   "norm_y_pos": 0.05250000231193774,
#   "is_centered": false,
#   "space_before": -8.151611328125,
#   "space_after": -4.813831329345703
#  },
#  {
#   "text": "Software Testing",
#   "page": 12,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 50.14617156982422,
#   "bbox": [
#    437.95001220703125,
#    50.14617156982422,
#    515.6878662109375,
#    61.25157165527344
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 16,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.0633158731942225,
#   "is_centered": false,
#   "space_before": -4.813831329345703,
#   "space_after": -4.299449920654297
#  },
#  {
#   "text": "Foundation Level Extension \u2013 Agile Tester",
#   "page": 12,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 58.42620086669922,
#   "bbox": [
#    74.42400360107422,
#    56.95212173461914,
#    265.065185546875,
#    70.23876190185547
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 41,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.07377045563977173,
#   "is_centered": false,
#   "space_before": -4.299449920654297,
#   "space_after": -8.57257080078125
#  },
#  {
#   "text": "Qualifications Board",
#   "page": 12,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 61.66619110107422,
#   "bbox": [
#    430.75,
#    61.66619110107422,
#    522.8402099609375,
#    72.77159118652344
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 20,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.07786135240034624,
#   "is_centered": false,
#   "space_before": -8.57257080078125,
#   "space_after": 50.20458984375
#  },
#  {
#   "text": "4. References",
#   "page": 12,
#   "avg_font_size": 15.960000038146973,
#   "y_position": 122.97618103027344,
#   "bbox": [
#    70.94400024414062,
#    122.97618103027344,
#    184.21214294433594,
#    140.77157592773438
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 13,
#   "starts_with_numbering": true,
#   "relative_font_size": 1.602409642384234,
#   "norm_y_pos": 0.15527295584630485,
#   "is_centered": false,
#   "space_before": 50.20458984375,
#   "space_after": 30.6221923828125
#  },
#  {
#   "text": "4.1 Trademarks",
#   "page": 12,
#   "avg_font_size": 14.039999961853027,
#   "y_position": 171.39376831054688,
#   "bbox": [
#    70.94400024414062,
#    171.39376831054688,
#    176.55291748046875,
#    187.04837036132812
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 14,
#   "starts_with_numbering": true,
#   "relative_font_size": 1.40963855038685,
#   "norm_y_pos": 0.21640627311937738,
#   "is_centered": false,
#   "space_before": 30.6221923828125,
#   "space_after": 7.837860107421875
#  },
#  {
#   "text": "The following registered trademarks and service marks are used in this document:",
#   "page": 12,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 194.88623046875,
#   "bbox": [
#    70.94400024414062,
#    194.88623046875,
#    436.22711181640625,
#    205.9916229248047
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 80,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.2460684728140783,
#   "is_centered": true,
#   "space_before": 7.837860107421875,
#   "space_after": 13.04400634765625
#  },
#  {
#   "text": "ISTQB\u00ae is a registered trademark of the International Software Testing Qualifications Board",
#   "page": 12,
#   "avg_font_size": 8.800000031789144,
#   "y_position": 220.92169189453125,
#   "bbox": [
#    70.94400024414062,
#    219.03562927246094,
#    477.04315185546875,
#    232.02708435058594
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 91,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.8835341397378659,
#   "norm_y_pos": 0.2789415301698627,
#   "is_centered": true,
#   "space_before": 13.04400634765625,
#   "space_after": 25.436691284179688
#  },
#  {
#   "text": "4.2 Documents and Web Sites",
#   "page": 12,
#   "avg_font_size": 14.039999961853027,
#   "y_position": 257.4637756347656,
#   "bbox": [
#    70.94400024414062,
#    257.4637756347656,
#    267.7581481933594,
#    273.1183776855469
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 27,
#   "starts_with_numbering": true,
#   "relative_font_size": 1.40963855038685,
#   "norm_y_pos": 0.32508052479137073,
#   "is_centered": false,
#   "space_before": 25.436691284179688,
#   "space_after": 7.71783447265625
#  },
#  {
#   "text": "Identifier Reference",
#   "page": 12,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 280.8362121582031,
#   "bbox": [
#    76.34400177001953,
#    280.8362121582031,
#    244.36508178710938,
#    291.9416198730469
#   ],
#   "font_name": "Arial,Bold",
#   "is_bold": true,
#   "is_all_caps": false,
#   "text_len": 20,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.3545911769674282,
#   "is_centered": false,
#   "space_before": 7.71783447265625,
#   "space_after": 3.534576416015625
#  },
#  {
#   "text": "[ISTQB-Web] Web site of the International Software Testing Qualifications Board. Refer",
#   "page": 12,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 295.4761962890625,
#   "bbox": [
#    76.34400177001953,
#    295.4761962890625,
#    520.4761962890625,
#    306.58160400390625
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 86,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.37307600541548297,
#   "is_centered": true,
#   "space_before": 3.534576416015625,
#   "space_after": 0.41461181640625
#  },
#  {
#   "text": "to this website for the latest ISTQB Glossary and Syllabi. (www.istqb.org)",
#   "page": 12,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 306.9962158203125,
#   "bbox": [
#    193.33999633789062,
#    306.9962158203125,
#    518.9476928710938,
#    318.10162353515625
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 74,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.38762148462160667,
#   "is_centered": true,
#   "space_before": 0.41461181640625,
#   "space_after": 400.5859375
#  },
#  {
#   "text": "Version 2014 Page 12 of 12 May 31, 2014",
#   "page": 12,
#   "avg_font_size": 9.960000038146973,
#   "y_position": 718.6875610351562,
#   "bbox": [
#    76.58399963378906,
#    718.6875610351562,
#    533.1344604492188,
#    730.081787109375
#   ],
#   "font_name": "Trebuchet MS",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 39,
#   "starts_with_numbering": false,
#   "relative_font_size": 1.0000000038300172,
#   "norm_y_pos": 0.9074337891858033,
#   "is_centered": true,
#   "space_before": 400.5859375,
#   "space_after": 6.8082275390625
#  },
#  {
#   "text": "\u00a9 International Software Testing Qualifications Board",
#   "page": 12,
#   "avg_font_size": 6.0,
#   "y_position": 736.8900146484375,
#   "bbox": [
#    76.58399963378906,
#    736.8900146484375,
#    219.2940216064453,
#    743.5800170898438
#   ],
#   "font_name": "Arial",
#   "is_bold": false,
#   "is_all_caps": false,
#   "text_len": 53,
#   "starts_with_numbering": false,
#   "relative_font_size": 0.6024096385542168,
#   "norm_y_pos": 0.9304166851621686,
#   "is_centered": false,
#   "space_before": 6.8082275390625,
#   "space_after": -1
#  }
# ]

# %% [markdown]
# Creating Labeled dataset

# %%
from thefuzz import fuzz
import pandas as pd

def create_labeled_dataset(featured_lines, ground_truth_headings, ground_truth_title, fuzz_threshold=70):
    """
    Assigns a label to each line using fuzzy matching against ground truth.
    
    Labels: 'Title', 'H1', 'H2', 'H3', 'Body Text'
    """
    
    # --- 1. Find and label the main Title first ---
    # Heuristic: The line on page 1 with the largest font size is likely the title.
    # We compare it against the ground_truth_title for confirmation.
    page_1_lines = [line for line in featured_lines if line['page'] == 1]
    
    if page_1_lines:
        # Find the best match for the title on page 1
        best_title_match_score = 0
        best_title_candidate = None
        
        for line in page_1_lines:
            score = fuzz.ratio(line['text'].strip().lower(), ground_truth_title.strip().lower())
            if score > best_title_match_score:
                best_title_match_score = score
                best_title_candidate = line
        
        # If we have a good match, label it and give it a unique ID to ignore later
        if best_title_candidate and best_title_match_score > fuzz_threshold:
            best_title_candidate['label'] = 'Title'
            # Use bbox as a unique identifier for the line
            best_title_candidate['id'] = str(best_title_candidate['bbox'])
    
    
    # --- 2. Label H1, H2, H3 headings ---
    # Create a quick lookup for ground truth headings by page
    gt_headings_by_page = {}
    for h in ground_truth_headings:
        page = h['page']
        if page not in gt_headings_by_page:
            gt_headings_by_page[page] = []
        gt_headings_by_page[page].append(h)
        
    # Iterate through every line to label it
    for line in featured_lines:
        # Skip lines we've already labeled (i.e., the Title)
        if 'label' in line:
            continue

        # Set default label
        line['label'] = 'Body Text'
        line['id'] = str(line['bbox'])

        page_num = line['page']
        
        # Only search for matches on the correct page
        if page_num in gt_headings_by_page:
            best_match_score = 0
            best_match_level = ''
            
            for gt_heading in gt_headings_by_page[page_num]:
                # Calculate fuzzy match score
                score = fuzz.ratio(line['text'].strip(), gt_heading['text'].strip())
                
                if score > best_match_score:
                    best_match_score = score
                    best_match_level = gt_heading['level']
            
            # If the best match is strong enough, assign the label
            if best_match_score > fuzz_threshold:
                line['label'] = best_match_level

    return featured_lines

# %%
import json

with open(output_filename, 'r', encoding='utf-8') as f:
    out = json.load(f)

labeled_lines = create_labeled_dataset(
    featured_lines, 
    out['outline'], 
    out['title']
)

df = pd.DataFrame(labeled_lines)
df.to_csv('o.csv',index=False)
